# %% [markdown]
# # Deploy and monitor a machine learning workflow for Image Classification

# %% [markdown]
# ## Setting up this notebook
#
# Notes about the instance size and kernel setup: this notebook has been tested on
#
# 1. The `Python 3 (Data Science)` kernel
# 2. The `ml.t3.medium` Sagemaker notebook instance
#
# ## Data Staging
#
# We'll use a sample dataset called CIFAR to simulate the challenges Scones Unlimited are facing in Image Classification. In order to start working with CIFAR we'll need to:
#
# 1. Extract the data from a hosting service
# 2. Transform it into a usable shape and format
# 3. Load it into a production system
#
# In other words, we're going to do some simple ETL!
#
# ### 1. Extract the data from the hosting service
#
# In the cell below, define a function `extract_cifar_data` that extracts python version of the CIFAR-100 dataset. The CIFAR dataaset is open source and generously hosted by the University of Toronto at: https://www.cs.toronto.edu/~kriz/cifar-100-python.tar.gz

# %%
import requests

def extract_cifar_data(url, filename="cifar.tar.gz"):
    """A function for extracting the CIFAR-100 dataset and storing it as a gzipped file
    
    Arguments:
    url      -- the URL where the dataset is hosted
    filename -- the full path where the dataset will be written
    
    """
    r = requests.get('https://www.cs.toronto.edu/~kriz/cifar-100-python.tar.gz')
    with open(filename, "wb") as file_context:
        file_context.write(r.content)
    return

# %% [markdown]
# Let's test it out! Run the following cell and check whether a new file `cifar.tar.gz` is created in the file explorer.

# %%
extract_cifar_data("https://www.cs.toronto.edu/~kriz/cifar-100-python.tar.gz")

# %% [markdown]
# ### 2. Transform the data into a usable shape and format
#
# Clearly, distributing the data as a gzipped archive makes sense for the hosting service! It saves on bandwidth, storage, and it's a widely-used archive format. In fact, it's so widely used that the Python community ships a utility for working with them, `tarfile`, as part of its Standard Library. Execute the following cell to decompress your extracted dataset:

# %%
import tarfile

with tarfile.open("cifar.tar.gz", "r:gz") as tar:
    tar.extractall()

# %% [markdown]
# A new folder `cifar-100-python` should be created, containing `meta`, `test`, and `train` files. These files are `pickles` and the [CIFAR homepage](https://www.cs.toronto.edu/~kriz/cifar.html) provides a simple script that can be used to load them. We've adapted the script below for you to run:

# %%
import pickle

with open("./cifar-100-python/meta", "rb") as f:
    dataset_meta = pickle.load(f, encoding='bytes')

with open("./cifar-100-python/test", "rb") as f:
    dataset_test = pickle.load(f, encoding='bytes')

with open("./cifar-100-python/train", "rb") as f:
    dataset_train = pickle.load(f, encoding='bytes')

# %%
# Feel free to explore the datasets

dataset_train.keys()
# Out:
# dict_keys([b'filenames', b'batch_label', b'fine_labels', b'coarse_labels', b'data'])

# %% [markdown]
# As documented on the homepage, `b'data'` contains rows of 3073 unsigned integers, representing three channels (red, green, and blue) for one 32x32 pixel image per row.

# %%
32*32*3
# Out:
# 3072

# %% [markdown]
# For a simple gut-check, let's transform one of our images. Each 1024 items in a row is a channel (red, green, then blue). Each 32 items in the channel are a row in the 32x32 image. Using python, we can stack these channels into a 32x32x3 array, and save it as a PNG file:

# %%
import numpy as np

# Each 1024 in a row is a channel (red, green, then blue)
row = dataset_train[b'data'][0]
red, green, blue = row[0:1024], row[1024:2048], row[2048:]

# Each 32 items in the channel are a row in the 32x32 image
red = red.reshape(32,32)
green = green.reshape(32,32)
blue = blue.reshape(32,32)

# Combine the channels into a 32x32x3 image!
combined = np.dstack((red,green,blue))

# %% [markdown]
# For a more concise version, consider the following:

# %%
# All in one:
test_image = np.dstack((
    row[0:1024].reshape(32,32),
    row[1024:2048].reshape(32,32),
    row[2048:].reshape(32,32)
))

# %%
import matplotlib.pyplot as plt
plt.imshow(test_image)
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %% [markdown]
# Looks like a cow! Let's check the label. `dataset_meta` contains label names in order, and `dataset_train` has a list of labels for each row.

# %%
dataset_train[b'fine_labels'][0]
# Out:
# 19

# %% [markdown]
# Our image has a label of `19`, so let's see what the 19th item is in the list of label names.

# %%
print(dataset_meta[b'fine_label_names'][19])
# Out:
# b'cattle'

# %% [markdown]
# Ok! 'cattle' sounds about right. By the way, using the previous two lines we can do:

# %%
n = 0
print(dataset_meta[b'fine_label_names'][dataset_train[b'fine_labels'][n]])
# Out:
# b'cattle'

# %% [markdown]
# Now we know how to check labels, is there a way that we can also check file names? `dataset_train` also contains a `b'filenames'` key. Let's see what we have here:

# %%
print(dataset_train[b'filenames'][0])
# Out:
# b'bos_taurus_s_000507.png'

# %% [markdown]
# "Taurus" is the name of a subspecies of cattle, so this looks like a pretty reasonable filename. To save an image we can also do:

# %%
plt.imsave("file.png", test_image)

# %% [markdown]
# Your new PNG file should now appear in the file explorer -- go ahead and pop it open to see!
#
# Now that you know how to reshape the images, save them as files, and capture their filenames and labels, let's just capture all the bicycles and motorcycles and save them. Scones Unlimited can use a model that tells these apart to route delivery drivers automatically.
#
# In the following cell, identify the label numbers for Bicycles and Motorcycles:

# %%
import pandas as pd

# Todo: Filter the dataset_train and dataset_meta objects to find the label numbers for Bicycle and Motorcycles
label_data = dataset_meta[b'fine_label_names']
bicyle_data = label_data.index(b'bicycle')
motorcycle_data = label_data.index(b'motorcycle')

# %% [markdown]
# Good job! We only need objects with label 8 and 48 -- this drastically simplifies our handling of the data! Below we construct a dataframe for you, and you can safely drop the rows that don't contain observations about bicycles and motorcycles. Fill in the missing lines below to drop all other rows:

# %%
#Construct the dataframe
df_train = pd.DataFrame({
    "filenames": dataset_train[b'filenames'],
    "labels": dataset_train[b'fine_labels'],
    "row": range(len(dataset_train[b'filenames']))
})

# Drop all rows from df_train where label is not 8 or 48
df_train = df_train[df_train['labels'].isin([8, 48])]

# Decode df_train.filenames so they are regular strings
df_train["filenames"] = df_train["filenames"].apply(
    lambda x: x.decode("utf-8")
)


df_test = pd.DataFrame({
    "filenames": dataset_test[b'filenames'],
    "labels": dataset_test[b'fine_labels'],
    "row": range(len(dataset_test[b'filenames']))
})

# Drop all rows from df_test where label is not 8 or 48
df_test = df_test[df_test['labels'].isin([8, 48])]
# Decode df_test.filenames so they are regular strings
df_test["filenames"] = df_test["filenames"].apply(
    lambda x: x.decode("utf-8")
)

# %% [markdown]
# Now that the data is filtered for just our classes, we can save all our images.

# %%
# !mkdir ./train
# !mkdir ./test
# Out:
# mkdir: cannot create directory ‘./train’: File exists
# mkdir: cannot create directory ‘./test’: File exists

# %% [markdown]
# In the previous sections we introduced you to several key snippets of code:
#
# 1. Grabbing the image data:
#
# ```python
# dataset_train[b'data'][0]
# ```
#
# 2. A simple idiom for stacking the image data into the right shape
#
# ```python
# import numpy as np
# np.dstack((
#     row[0:1024].reshape(32,32),
#     row[1024:2048].reshape(32,32),
#     row[2048:].reshape(32,32)
# ))
# ```
#
# 3. A simple `matplotlib` utility for saving images
#
# ```python
# plt.imsave(path+row['filenames'], target)
# ```
#
# Compose these together into a function that saves all the images into the `./test` and `./train` directories. Use the comments in the body of the `save_images` function below to guide your construction of the function:

# %%
import os

def save_images(img_data_row_num, img_filename, target_folder_path, img_dataset):
    """
    Save an image from a dataset to a target folder
    Arguments:
    img_data_row_num -- Row number in the dataset containing the image data
    img_filename -- Filename with which the image needs to be saved
    target_folder_path -- Target folder path where the image will be saved
    img_dataset  -- Original dataset containing the image data 
    """
    # Grab the image data in row-major form
    img = img_dataset[b'data'][img_data_row_num]
    # Consolidated stacking/reshaping from earlier
    target = np.dstack((
        img[0:1024].reshape(32,32),
        img[1024:2048].reshape(32,32),
        img[2048:].reshape(32,32)
    ))

    # Ensure the target folder exists
    os.makedirs(target_folder_path, exist_ok=True)

    # Construct the full file path
    file_path = os.path.join(target_folder_path, img_filename)
    # Save the image
    plt.imsave(file_path, target)

    # Return any signal data you want for debugging
    return f'image saved to {file_path}'
# TODO: save ALL images using the save_images function
for df_row in df_train.itertuples():
    print(save_images(
        df_row.row,
        df_row.filenames,
        "./train",
        dataset_train
    ))

for df_row in df_test.itertuples():
    print(save_images(
        df_row.row,
        df_row.filenames,
        "./test",
        dataset_test
    ))
# Out:
# image saved to ./train/bike_s_000682.png
# image saved to ./train/bike_s_000127.png
# image saved to ./train/cycle_s_002598.png
# image saved to ./train/minibike_s_000824.png
# image saved to ./train/motorcycle_s_001856.png
# image saved to ./train/bicycle_s_000537.png
# image saved to ./train/moped_s_000169.png
# image saved to ./train/motorcycle_s_001453.png
# image saved to ./train/safety_bike_s_000482.png
# image saved to ./train/dirt_bike_s_000124.png
# image saved to ./train/minibike_s_001863.png
# image saved to ./train/minibike_s_001177.png
# image saved to ./train/motorcycle_s_001792.png
# image saved to ./train/minibike_s_001969.png
# image saved to ./train/velocipede_s_001585.png
# image saved to ./train/moped_s_000035.png
# image saved to ./train/bike_s_000256.png
# image saved to ./train/minibike_s_000571.png
# image saved to ./train/motorcycle_s_001119.png
# image saved to ./train/moped_s_000009.png
# image saved to ./train/ordinary_bicycle_s_000023.png
# image saved to ./train/motorcycle_s_001693.png
# image saved to ./train/safety_bicycle_s_001570.png
# image saved to ./train/safety_bike_s_000989.png
# image saved to ./train/bicycle_s_001673.png
# image saved to ./train/ordinary_bicycle_s_000100.png
# image saved to ./train/bike_s_000544.png
# image saved to ./train/motorcycle_s_001368.png
# image saved to ./train/bicycle_s_000392.png
# image saved to ./train/motorbike_s_000221.png
# image saved to ./train/safety_bike_s_000311.png
# image saved to ./train/cycle_s_001745.png
# image saved to ./train/motorcycle_s_002030.png
# image saved to ./train/motorcycle_s_000074.png
# image saved to ./train/cycle_s_002978.png
# image saved to ./train/bike_s_001679.png
# image saved to ./train/bicycle_s_000536.png
# image saved to ./train/bike_s_000926.png
# image saved to ./train/motorcycle_s_000070.png
# image saved to ./train/safety_bicycle_s_000655.png
# image saved to ./train/safety_bicycle_s_000427.png
# image saved to ./train/minibike_s_000324.png
# image saved to ./train/minibike_s_001631.png
# image saved to ./train/motorcycle_s_000629.png
# image saved to ./train/motorcycle_s_000605.png
# image saved to ./train/motorcycle_s_001973.png
# image saved to ./train/bike_s_000555.png
# image saved to ./train/bicycle_s_002762.png
# image saved to ./train/bicycle_s_000778.png
# image saved to ./train/bike_s_001613.png
# image saved to ./train/motorcycle_s_001180.png
# image saved to ./train/minibike_s_001279.png
# image saved to ./train/minibike_s_000451.png
# image saved to ./train/motorbike_s_000346.png
# image saved to ./train/minibike_s_000117.png
# image saved to ./train/bicycle_s_001448.png
# image saved to ./train/motorcycle_s_000790.png
# image saved to ./train/bicycle_s_002373.png
# image saved to ./train/safety_bicycle_s_001202.png
# image saved to ./train/motorcycle_s_000001.png
# image saved to ./train/bike_s_001882.png
# image saved to ./train/bike_s_001113.png
# image saved to ./train/minibike_s_000362.png
# image saved to ./train/cycle_s_000718.png
# image saved to ./train/velocipede_s_001338.png
# image saved to ./train/minibike_s_001972.png
# image saved to ./train/ordinary_bicycle_s_000107.png
# image saved to ./train/motorcycle_s_000776.png
# image saved to ./train/safety_bike_s_000934.png
# image saved to ./train/bicycle_s_002218.png
# image saved to ./train/safety_bicycle_s_001240.png
# image saved to ./train/ordinary_bicycle_s_000355.png
# image saved to ./train/motorcycle_s_000454.png
# image saved to ./train/motorcycle_s_000245.png
# image saved to ./train/minibike_s_000743.png
# image saved to ./train/safety_bike_s_000830.png
# image saved to ./train/minibike_s_001573.png
# image saved to ./train/motorbike_s_000141.png
# image saved to ./train/minibike_s_000652.png
# image saved to ./train/motorbike_s_000058.png
# image saved to ./train/bicycle_s_000279.png
# image saved to ./train/safety_bike_s_001608.png
# image saved to ./train/bicycle_s_000522.png
# image saved to ./train/bicycle_s_002569.png
# image saved to ./train/bicycle_s_000829.png
# image saved to ./train/velocipede_s_000586.png
# image saved to ./train/dirt_bike_s_000017.png
# image saved to ./train/cycle_s_001640.png
# image saved to ./train/bicycle_s_000282.png
# image saved to ./train/motorcycle_s_000713.png
# image saved to ./train/bike_s_000035.png
# image saved to ./train/bike_s_000299.png
# image saved to ./train/minibike_s_002198.png
# image saved to ./train/safety_bicycle_s_001253.png
# image saved to ./train/minibike_s_000110.png
# image saved to ./train/motorcycle_s_001370.png
# image saved to ./train/motorcycle_s_001363.png
# image saved to ./train/ordinary_bicycle_s_000060.png
# image saved to ./train/minibike_s_001653.png
# image saved to ./train/bicycle_s_001338.png
# image saved to ./train/cycle_s_002053.png
# image saved to ./train/velocipede_s_001056.png
# image saved to ./train/minibike_s_000402.png
# image saved to ./train/motorbike_s_000124.png
# image saved to ./train/cycle_s_002638.png
# image saved to ./train/velocipede_s_000949.png
# image saved to ./train/safety_bike_s_000921.png
# image saved to ./train/ordinary_bicycle_s_000297.png
# image saved to ./train/motorcycle_s_001580.png
# image saved to ./train/velocipede_s_000139.png
# image saved to ./train/bicycle_s_000561.png
# image saved to ./train/ordinary_bicycle_s_000161.png
# image saved to ./train/minibike_s_000518.png
# image saved to ./train/motorcycle_s_000167.png
# image saved to ./train/cycle_s_000318.png
# image saved to ./train/velocipede_s_001958.png
# image saved to ./train/ordinary_bicycle_s_000201.png
# image saved to ./train/bike_s_001462.png
# image saved to ./train/bicycle_s_000437.png
# image saved to ./train/velocipede_s_000825.png
# image saved to ./train/safety_bike_s_000100.png
# image saved to ./train/minibike_s_000654.png
# image saved to ./train/bicycle_s_000021.png
# image saved to ./train/moped_s_000030.png
# image saved to ./train/velocipede_s_001142.png
# image saved to ./train/motorbike_s_000117.png
# image saved to ./train/ordinary_bicycle_s_000036.png
# image saved to ./train/motorcycle_s_000787.png
# image saved to ./train/bike_s_000516.png
# image saved to ./train/motorcycle_s_000256.png
# image saved to ./train/bicycle_s_002299.png
# image saved to ./train/velocipede_s_001883.png
# image saved to ./train/motorcycle_s_002143.png
# image saved to ./train/cycle_s_000899.png
# image saved to ./train/bicycle_s_002436.png
# image saved to ./train/safety_bicycle_s_000255.png
# image saved to ./train/minibike_s_000565.png
# image saved to ./train/bike_s_000034.png
# image saved to ./train/motorcycle_s_001064.png
# image saved to ./train/minibike_s_001017.png
# image saved to ./train/motorbike_s_000172.png
# image saved to ./train/motorcycle_s_000923.png
# image saved to ./train/cycle_s_000583.png
# image saved to ./train/motorcycle_s_000991.png
# image saved to ./train/motorbike_s_000541.png
# image saved to ./train/motorcycle_s_001303.png
# image saved to ./train/safety_bike_s_000567.png
# image saved to ./train/minibike_s_000350.png
# image saved to ./train/motorcycle_s_001905.png
# image saved to ./train/bicycle_s_001247.png
# image saved to ./train/bicycle_s_001693.png
# image saved to ./train/bicycle_s_002258.png
# image saved to ./train/safety_bike_s_001552.png
# image saved to ./train/cycle_s_002651.png
# image saved to ./train/bicycle_s_000759.png
# image saved to ./train/motorcycle_s_001176.png
# image saved to ./train/ordinary_bicycle_s_000432.png
# image saved to ./train/minibike_s_000526.png
# image saved to ./train/safety_bicycle_s_001049.png
# image saved to ./train/minibike_s_001827.png
# image saved to ./train/bike_s_001072.png
# image saved to ./train/bike_s_001876.png
# image saved to ./train/minibike_s_001511.png
# image saved to ./train/bike_s_000237.png
# image saved to ./train/motorbike_s_000254.png
# image saved to ./train/bicycle_s_000180.png
# image saved to ./train/safety_bicycle_s_000359.png
# image saved to ./train/motorcycle_s_000220.png
# image saved to ./train/motorcycle_s_002225.png
# image saved to ./train/minibike_s_001185.png
# image saved to ./train/motorcycle_s_000025.png
# image saved to ./train/safety_bike_s_000058.png
# image saved to ./train/dirt_bike_s_000030.png
# image saved to ./train/minibike_s_002009.png
# image saved to ./train/bicycle_s_000753.png
# image saved to ./train/safety_bicycle_s_001320.png
# image saved to ./train/motorcycle_s_001287.png
# image saved to ./train/ordinary_bicycle_s_000451.png
# image saved to ./train/minibike_s_000885.png
# image saved to ./train/motorcycle_s_000418.png
# image saved to ./train/velocipede_s_000282.png
# image saved to ./train/cycle_s_001474.png
# image saved to ./train/bicycle_s_000667.png
# image saved to ./train/minibike_s_001546.png
# image saved to ./train/bicycle_s_001452.png
# image saved to ./train/motorcycle_s_000978.png
# image saved to ./train/motorcycle_s_000447.png
# image saved to ./train/minibike_s_000146.png
# image saved to ./train/motorcycle_s_000300.png
# image saved to ./train/safety_bicycle_s_001381.png
# image saved to ./train/bike_s_001519.png
# image saved to ./train/minibike_s_001689.png
# image saved to ./train/bike_s_001320.png
# image saved to ./train/bike_s_000722.png
# image saved to ./train/motorcycle_s_000508.png
# image saved to ./train/motorcycle_s_002105.png
# image saved to ./train/minibike_s_000165.png
# image saved to ./train/cycle_s_002703.png
# image saved to ./train/ordinary_bicycle_s_000216.png
# image saved to ./train/motorcycle_s_001610.png
# image saved to ./train/cycle_s_002779.png
# image saved to ./train/bicycle_s_000668.png
# image saved to ./train/minibike_s_002186.png
# image saved to ./train/bike_s_002118.png
# image saved to ./train/safety_bike_s_001472.png
# image saved to ./train/ordinary_bicycle_s_000016.png
# image saved to ./train/motorcycle_s_001384.png
# image saved to ./train/motorcycle_s_000431.png
# image saved to ./train/bike_s_000302.png
# image saved to ./train/velocipede_s_000659.png
# image saved to ./train/motorcycle_s_001585.png
# image saved to ./train/bike_s_001027.png
# image saved to ./train/bicycle_s_000396.png
# image saved to ./train/minibike_s_000149.png
# image saved to ./train/velocipede_s_000702.png
# image saved to ./train/ordinary_bicycle_s_000155.png
# image saved to ./train/cycle_s_003122.png
# image saved to ./train/motorbike_s_000021.png
# image saved to ./train/safety_bicycle_s_001026.png
# image saved to ./train/bike_s_001375.png
# image saved to ./train/safety_bicycle_s_000533.png
# image saved to ./train/bike_s_000021.png
# image saved to ./train/minibike_s_000968.png
# image saved to ./train/minibike_s_001873.png
# image saved to ./train/bicycle_s_000463.png
# image saved to ./train/bike_s_001839.png
# image saved to ./train/minibike_s_000340.png
# image saved to ./train/minibike_s_000831.png
# image saved to ./train/motorcycle_s_001273.png
# image saved to ./train/motorcycle_s_000807.png
# image saved to ./train/bicycle_s_000156.png
# image saved to ./train/motorcycle_s_000732.png
# image saved to ./train/dirt_bike_s_000119.png
# image saved to ./train/bicycle_s_000231.png
# image saved to ./train/ordinary_bicycle_s_000056.png
# image saved to ./train/ordinary_bicycle_s_000022.png
# image saved to ./train/safety_bicycle_s_001243.png
# image saved to ./train/motorcycle_s_000894.png
# image saved to ./train/motorcycle_s_001397.png
# image saved to ./train/motorcycle_s_000542.png
# image saved to ./train/motorcycle_s_000834.png
# image saved to ./train/motorcycle_s_001238.png
# image saved to ./train/minibike_s_000567.png
# image saved to ./train/minibike_s_001512.png
# image saved to ./train/bike_s_001945.png
# image saved to ./train/cycle_s_003148.png
# image saved to ./train/safety_bicycle_s_000019.png
# image saved to ./train/safety_bicycle_s_000167.png
# image saved to ./train/motorcycle_s_001407.png
# image saved to ./train/velocipede_s_001225.png
# image saved to ./train/moped_s_000168.png
# image saved to ./train/bicycle_s_000071.png
# image saved to ./train/minibike_s_002030.png
# image saved to ./train/minibike_s_001294.png
# image saved to ./train/minibike_s_001767.png
# image saved to ./train/safety_bike_s_000984.png
# image saved to ./train/bicycle_s_000782.png
# image saved to ./train/ordinary_bicycle_s_000095.png
# image saved to ./train/cycle_s_001286.png
# image saved to ./train/bike_s_001116.png
# image saved to ./train/motorcycle_s_002065.png
# image saved to ./train/ordinary_bicycle_s_000433.png
# image saved to ./train/motorcycle_s_002221.png
# image saved to ./train/safety_bike_s_000054.png
# image saved to ./train/bicycle_s_001174.png
# image saved to ./train/bicycle_s_002222.png
# image saved to ./train/velocipede_s_001361.png
# image saved to ./train/safety_bike_s_001012.png
# image saved to ./train/minibike_s_000244.png
# image saved to ./train/bicycle_s_000861.png
# image saved to ./train/minibike_s_000566.png
# image saved to ./train/motorcycle_s_001244.png
# image saved to ./train/bicycle_s_002715.png
# image saved to ./train/safety_bike_s_000963.png
# image saved to ./train/motorcycle_s_001765.png
# image saved to ./train/velocipede_s_000021.png
# image saved to ./train/motorcycle_s_000580.png
# image saved to ./train/bike_s_001226.png
# image saved to ./train/motorcycle_s_000440.png
# image saved to ./train/motorcycle_s_000144.png
# image saved to ./train/cycle_s_002844.png
# image saved to ./train/minibike_s_000485.png
# image saved to ./train/ordinary_bicycle_s_000426.png
# image saved to ./train/minibike_s_002196.png
# image saved to ./train/bike_s_001897.png
# image saved to ./train/cycle_s_001374.png
# image saved to ./train/motorcycle_s_000585.png
# image saved to ./train/bike_s_000026.png
# image saved to ./train/bicycle_s_000235.png
# image saved to ./train/minibike_s_000108.png
# image saved to ./train/motorcycle_s_000072.png
# image saved to ./train/motorcycle_s_002234.png
# image saved to ./train/bicycle_s_000785.png
# image saved to ./train/motorcycle_s_000669.png
# image saved to ./train/bicycle_s_000051.png
# image saved to ./train/bike_s_001093.png
# image saved to ./train/velocipede_s_000049.png
# image saved to ./train/bike_s_000023.png
# image saved to ./train/motorcycle_s_001696.png
# image saved to ./train/safety_bicycle_s_001113.png
# image saved to ./train/motorcycle_s_000451.png
# image saved to ./train/velocipede_s_000485.png
# image saved to ./train/motorcycle_s_001753.png
# image saved to ./train/cycle_s_001439.png
# image saved to ./train/minibike_s_002038.png
# image saved to ./train/bicycle_s_000147.png
# image saved to ./train/cycle_s_002399.png
# image saved to ./train/motorcycle_s_001565.png
# image saved to ./train/bicycle_s_000159.png
# image saved to ./train/minibike_s_000035.png
# image saved to ./train/safety_bicycle_s_000239.png
# image saved to ./train/safety_bike_s_001640.png
# image saved to ./train/minibike_s_000698.png
# image saved to ./train/minibike_s_000967.png
# image saved to ./train/safety_bike_s_000381.png
# image saved to ./train/motorcycle_s_000216.png
# image saved to ./train/bike_s_000855.png
# image saved to ./train/motorcycle_s_001715.png
# image saved to ./train/motorcycle_s_002275.png
# image saved to ./train/safety_bike_s_001338.png
# image saved to ./train/safety_bicycle_s_001705.png
# image saved to ./train/minibike_s_000855.png
# image saved to ./train/bicycle_s_002132.png
# image saved to ./train/minibike_s_000218.png
# image saved to ./train/safety_bike_s_000178.png
# image saved to ./train/motorcycle_s_001584.png
# image saved to ./train/safety_bicycle_s_000162.png
# image saved to ./train/motorcycle_s_001392.png
# image saved to ./train/bicycle_s_001814.png
# image saved to ./train/motorbike_s_000362.png
# image saved to ./train/minibike_s_000519.png
# image saved to ./train/minibike_s_001417.png
# image saved to ./train/safety_bike_s_000277.png
# image saved to ./train/cycle_s_002090.png
# image saved to ./train/bicycle_s_001168.png
# image saved to ./train/minibike_s_000498.png
# image saved to ./train/motorcycle_s_001400.png
# image saved to ./train/motorcycle_s_000320.png
# image saved to ./train/minibike_s_001734.png
# image saved to ./train/cycle_s_002659.png
# image saved to ./train/bike_s_000990.png
# image saved to ./train/velocipede_s_000358.png
# image saved to ./train/safety_bicycle_s_000568.png
# image saved to ./train/motorcycle_s_000312.png
# image saved to ./train/motorcycle_s_001686.png
# image saved to ./train/cycle_s_001472.png
# image saved to ./train/minibike_s_000064.png
# image saved to ./train/safety_bike_s_001784.png
# image saved to ./train/motorcycle_s_002236.png
# image saved to ./train/minibike_s_000020.png
# image saved to ./train/motorcycle_s_001182.png
# image saved to ./train/bicycle_s_000781.png
# image saved to ./train/ordinary_bicycle_s_000167.png
# image saved to ./train/cycle_s_002666.png
# image saved to ./train/dirt_bike_s_000134.png
# image saved to ./train/bike_s_000015.png
# image saved to ./train/bike_s_001767.png
# image saved to ./train/motorcycle_s_001790.png
# image saved to ./train/bike_s_001915.png
# image saved to ./train/bike_s_001415.png
# image saved to ./train/motorbike_s_000578.png
# image saved to ./train/safety_bicycle_s_000532.png
# image saved to ./train/ordinary_bicycle_s_000049.png
# image saved to ./train/minibike_s_001639.png
# image saved to ./train/bike_s_000129.png
# image saved to ./train/minibike_s_001565.png
# image saved to ./train/bike_s_002203.png
# image saved to ./train/minibike_s_000401.png
# image saved to ./train/safety_bicycle_s_001608.png
# image saved to ./train/velocipede_s_000670.png
# image saved to ./train/safety_bicycle_s_000207.png
# image saved to ./train/motorcycle_s_001853.png
# image saved to ./train/bike_s_002222.png
# image saved to ./train/motorcycle_s_000004.png
# image saved to ./train/motorcycle_s_000496.png
# image saved to ./train/motorcycle_s_001492.png
# image saved to ./train/bike_s_001761.png
# image saved to ./train/velocipede_s_001299.png
# image saved to ./train/bike_s_000040.png
# image saved to ./train/cycle_s_003162.png
# image saved to ./train/velocipede_s_001880.png
# image saved to ./train/bike_s_002139.png
# image saved to ./train/bicycle_s_001583.png
# image saved to ./train/safety_bicycle_s_001706.png
# image saved to ./train/bike_s_001200.png
# image saved to ./train/motorcycle_s_000699.png
# image saved to ./train/cycle_s_000492.png
# image saved to ./train/cycle_s_000222.png
# image saved to ./train/motorcycle_s_002162.png
# image saved to ./train/minibike_s_000409.png
# image saved to ./train/cycle_s_001735.png
# image saved to ./train/bike_s_000657.png
# image saved to ./train/safety_bike_s_000643.png
# image saved to ./train/bike_s_000506.png
# image saved to ./train/minibike_s_001348.png
# image saved to ./train/moped_s_000065.png
# image saved to ./train/bicycle_s_002729.png
# image saved to ./train/bicycle_s_001687.png
# image saved to ./train/bicycle_s_002338.png
# image saved to ./train/motorcycle_s_000459.png
# image saved to ./train/bike_s_000593.png
# image saved to ./train/velocipede_s_001422.png
# image saved to ./train/ordinary_bicycle_s_000347.png
# image saved to ./train/minibike_s_001870.png
# image saved to ./train/bicycle_s_001757.png
# image saved to ./train/motorcycle_s_001016.png
# image saved to ./train/motorbike_s_000041.png
# image saved to ./train/bike_s_000522.png
# image saved to ./train/ordinary_bicycle_s_000104.png
# image saved to ./train/bike_s_000397.png
# image saved to ./train/minibike_s_000802.png
# image saved to ./train/trail_bike_s_000016.png
# image saved to ./train/motorcycle_s_000686.png
# image saved to ./train/velocipede_s_001935.png
# image saved to ./train/safety_bike_s_000165.png
# image saved to ./train/motorbike_s_000308.png
# image saved to ./train/bike_s_000018.png
# image saved to ./train/cycle_s_001976.png
# image saved to ./train/minibike_s_000741.png
# image saved to ./train/motorcycle_s_001236.png
# image saved to ./train/moped_s_000071.png
# image saved to ./train/bike_s_000164.png
# image saved to ./train/bike_s_001739.png
# image saved to ./train/bicycle_s_001388.png
# image saved to ./train/bicycle_s_000149.png
# image saved to ./train/motorcycle_s_002197.png
# image saved to ./train/motorcycle_s_000277.png
# image saved to ./train/motorcycle_s_001690.png
# image saved to ./train/minibike_s_002048.png
# image saved to ./train/motorcycle_s_000253.png
# image saved to ./train/safety_bike_s_001010.png
# image saved to ./train/motorcycle_s_000785.png
# image saved to ./train/ordinary_bicycle_s_000387.png
# image saved to ./train/cycle_s_001309.png
# image saved to ./train/motorcycle_s_002316.png
# image saved to ./train/motorcycle_s_000340.png
# image saved to ./train/moped_s_000124.png
# image saved to ./train/minibike_s_001917.png
# image saved to ./train/bicycle_s_000951.png
# image saved to ./train/motorcycle_s_000002.png
# image saved to ./train/motorcycle_s_001063.png
# image saved to ./train/motorcycle_s_001641.png
# image saved to ./train/bicycle_s_002129.png
# image saved to ./train/minibike_s_002182.png
# image saved to ./train/minibike_s_000427.png
# image saved to ./train/motorcycle_s_001438.png
# image saved to ./train/motorcycle_s_000126.png
# image saved to ./train/minibike_s_001865.png
# image saved to ./train/motorcycle_s_000456.png
# image saved to ./train/motorcycle_s_000252.png
# image saved to ./train/bicycle_s_000043.png
# image saved to ./train/bicycle_s_001928.png
# image saved to ./train/safety_bike_s_000173.png
# image saved to ./train/motorcycle_s_000696.png
# image saved to ./train/motorcycle_s_001413.png
# image saved to ./train/safety_bicycle_s_001303.png
# image saved to ./train/motorcycle_s_001220.png
# image saved to ./train/safety_bicycle_s_000079.png
# image saved to ./train/bicycle_s_001681.png
# image saved to ./train/cycle_s_002015.png
# image saved to ./train/cycle_s_002746.png
# image saved to ./train/minibike_s_001250.png
# image saved to ./train/safety_bicycle_s_000303.png
# image saved to ./train/bike_s_000392.png
# image saved to ./train/minibike_s_000408.png
# image saved to ./train/safety_bike_s_001355.png
# image saved to ./train/motorcycle_s_000076.png
# image saved to ./train/safety_bicycle_s_000322.png
# image saved to ./train/bike_s_002090.png
# image saved to ./train/motorcycle_s_000796.png
# image saved to ./train/motorbike_s_000225.png
# image saved to ./train/motorcycle_s_000050.png
# image saved to ./train/bike_s_000474.png
# image saved to ./train/motorcycle_s_000127.png
# image saved to ./train/motorcycle_s_002193.png
# image saved to ./train/bicycle_s_002374.png
# image saved to ./train/minibike_s_001558.png
# image saved to ./train/velocipede_s_001279.png
# image saved to ./train/minibike_s_001496.png
# image saved to ./train/bicycle_s_001411.png
# image saved to ./train/minibike_s_001072.png
# image saved to ./train/bicycle_s_001688.png
# image saved to ./train/safety_bike_s_000160.png
# image saved to ./train/minibike_s_000820.png
# image saved to ./train/ordinary_bicycle_s_000298.png
# image saved to ./train/bicycle_s_000314.png
# image saved to ./train/motorcycle_s_001862.png
# image saved to ./train/minibike_s_001575.png
# image saved to ./train/minibike_s_000709.png
# image saved to ./train/velocipede_s_000931.png
# image saved to ./train/safety_bike_s_000104.png
# image saved to ./train/motorcycle_s_001197.png
# image saved to ./train/motorbike_s_000115.png
# image saved to ./train/bicycle_s_002728.png
# image saved to ./train/safety_bike_s_001474.png
# image saved to ./train/bike_s_002024.png
# image saved to ./train/cycle_s_000666.png
# image saved to ./train/motorcycle_s_000617.png
# image saved to ./train/safety_bike_s_000461.png
# image saved to ./train/bike_s_001572.png
# image saved to ./train/motorcycle_s_000003.png
# image saved to ./train/bicycle_s_002029.png
# image saved to ./train/minibike_s_000701.png
# image saved to ./train/motorbike_s_000009.png
# image saved to ./train/minibike_s_001789.png
# image saved to ./train/motorcycle_s_000417.png
# image saved to ./train/motorcycle_s_000246.png
# image saved to ./train/minibike_s_000886.png
# image saved to ./train/motorcycle_s_000154.png
# image saved to ./train/minibike_s_001169.png
# image saved to ./train/cycle_s_002904.png
# image saved to ./train/motorcycle_s_000772.png
# image saved to ./train/velocipede_s_001158.png
# image saved to ./train/bicycle_s_002521.png
# image saved to ./train/minibike_s_001179.png
# image saved to ./train/bicycle_s_001111.png
# image saved to ./train/bicycle_s_001205.png
# image saved to ./train/bicycle_s_000435.png
# image saved to ./train/minibike_s_001771.png
# image saved to ./train/motorcycle_s_000545.png
# image saved to ./train/moped_s_000004.png
# image saved to ./train/velocipede_s_001358.png
# image saved to ./train/motorcycle_s_001402.png
# image saved to ./train/minibike_s_001836.png
# image saved to ./train/motorcycle_s_002067.png
# image saved to ./train/bicycle_s_002012.png
# image saved to ./train/motorcycle_s_000517.png
# image saved to ./train/minibike_s_001345.png
# image saved to ./train/minibike_s_000522.png
# image saved to ./train/motorcycle_s_000700.png
# image saved to ./train/motorcycle_s_001183.png
# image saved to ./train/velocipede_s_001874.png
# image saved to ./train/cycle_s_003006.png
# image saved to ./train/motorcycle_s_000170.png
# image saved to ./train/ordinary_bicycle_s_000419.png
# image saved to ./train/motorcycle_s_000284.png
# image saved to ./train/motorbike_s_000035.png
# image saved to ./train/dirt_bike_s_000005.png
# image saved to ./train/motorcycle_s_001784.png
# image saved to ./train/motorcycle_s_001848.png
# image saved to ./train/minibike_s_002046.png
# image saved to ./train/motorcycle_s_002317.png
# image saved to ./train/bike_s_001980.png
# image saved to ./train/safety_bike_s_000950.png
# image saved to ./train/bicycle_s_002237.png
# image saved to ./train/cycle_s_000042.png
# image saved to ./train/bike_s_000628.png
# image saved to ./train/bike_s_000005.png
# image saved to ./train/ordinary_bicycle_s_000324.png
# image saved to ./train/motorcycle_s_000346.png
# image saved to ./train/safety_bicycle_s_000789.png
# image saved to ./train/ordinary_bicycle_s_000011.png
# image saved to ./train/minibike_s_001157.png
# image saved to ./train/bike_s_000051.png
# image saved to ./train/motorcycle_s_000919.png
# image saved to ./train/velocipede_s_001514.png
# image saved to ./train/bike_s_001592.png
# image saved to ./train/ordinary_bicycle_s_000066.png
# image saved to ./train/bicycle_s_001470.png
# image saved to ./train/motorcycle_s_001695.png
# image saved to ./train/motorcycle_s_001215.png
# image saved to ./train/bike_s_002098.png
# image saved to ./train/bike_s_001928.png
# image saved to ./train/bicycle_s_001748.png
# image saved to ./train/motorcycle_s_001520.png
# image saved to ./train/safety_bicycle_s_000728.png
# image saved to ./train/motorcycle_s_000925.png
# image saved to ./train/safety_bike_s_000914.png
# image saved to ./train/safety_bike_s_001659.png
# image saved to ./train/safety_bike_s_000155.png
# image saved to ./train/bicycle_s_002153.png
# image saved to ./train/safety_bike_s_001715.png
# image saved to ./train/bicycle_s_000035.png
# image saved to ./train/bicycle_s_002669.png
# image saved to ./train/bike_s_002277.png
# image saved to ./train/ordinary_bicycle_s_000265.png
# image saved to ./train/bicycle_s_000369.png
# image saved to ./train/velocipede_s_001298.png
# image saved to ./train/minibike_s_001944.png
# image saved to ./train/motorcycle_s_002215.png
# image saved to ./train/ordinary_bicycle_s_000008.png
# image saved to ./train/bicycle_s_000491.png
# image saved to ./train/motorcycle_s_000146.png
# image saved to ./train/minibike_s_001261.png
# image saved to ./train/safety_bicycle_s_000140.png
# image saved to ./train/motorcycle_s_000407.png
# image saved to ./train/minibike_s_000099.png
# image saved to ./train/motorcycle_s_001767.png
# image saved to ./train/safety_bike_s_000263.png
# image saved to ./train/motorcycle_s_001205.png
# image saved to ./train/motorbike_s_000134.png
# image saved to ./train/safety_bike_s_000245.png
# image saved to ./train/motorcycle_s_000422.png
# image saved to ./train/minibike_s_000800.png
# image saved to ./train/minibike_s_001829.png
# image saved to ./train/minibike_s_002124.png
# image saved to ./train/bike_s_001414.png
# image saved to ./train/motorcycle_s_000423.png
# image saved to ./train/motorcycle_s_001435.png
# image saved to ./train/motorcycle_s_001237.png
# image saved to ./train/motorcycle_s_001878.png
# image saved to ./train/cycle_s_002093.png
# image saved to ./train/velocipede_s_000265.png
# image saved to ./train/bike_s_001847.png
# image saved to ./train/cycle_s_000463.png
# image saved to ./train/motorcycle_s_002140.png
# image saved to ./train/motorcycle_s_001246.png
# image saved to ./train/bike_s_001517.png
# image saved to ./train/motorcycle_s_000219.png
# image saved to ./train/motorbike_s_000501.png
# image saved to ./train/velocipede_s_001872.png
# image saved to ./train/motorcycle_s_001337.png
# image saved to ./train/motorcycle_s_000169.png
# image saved to ./train/motorcycle_s_000347.png
# image saved to ./train/ordinary_bicycle_s_000274.png
# image saved to ./train/safety_bicycle_s_000196.png
# image saved to ./train/bicycle_s_002049.png
# image saved to ./train/minibike_s_000010.png
# image saved to ./train/motorcycle_s_002121.png
# image saved to ./train/motorbike_s_000060.png
# image saved to ./train/motorbike_s_000534.png
# image saved to ./train/ordinary_bicycle_s_000286.png
# image saved to ./train/bicycle_s_000723.png
# image saved to ./train/bicycle_s_000066.png
# image saved to ./train/motorcycle_s_000741.png
# image saved to ./train/minibike_s_001168.png
# image saved to ./train/bike_s_000001.png
# image saved to ./train/minibike_s_001491.png
# image saved to ./train/motorcycle_s_000430.png
# image saved to ./train/motorcycle_s_000026.png
# image saved to ./train/bicycle_s_002448.png
# image saved to ./train/cycle_s_001412.png
# image saved to ./train/motorcycle_s_000714.png
# image saved to ./train/motorcycle_s_000319.png
# image saved to ./train/safety_bicycle_s_001254.png
# image saved to ./train/ordinary_bicycle_s_000205.png
# image saved to ./train/bicycle_s_002400.png
# image saved to ./train/motorcycle_s_001126.png
# image saved to ./train/bike_s_000364.png
# image saved to ./train/ordinary_bicycle_s_000096.png
# image saved to ./train/bike_s_000204.png
# image saved to ./train/motorcycle_s_001181.png
# image saved to ./train/minibike_s_001450.png
# image saved to ./train/minibike_s_000130.png
# image saved to ./train/motorcycle_s_002214.png
# image saved to ./train/motorcycle_s_001263.png
# image saved to ./train/minibike_s_000568.png
# image saved to ./train/bicycle_s_000774.png
# image saved to ./train/ordinary_bicycle_s_000125.png
# image saved to ./train/minibike_s_001731.png
# image saved to ./train/bicycle_s_000243.png
# image saved to ./train/motorcycle_s_000029.png
# image saved to ./train/velocipede_s_000023.png
# image saved to ./train/minibike_s_001701.png
# image saved to ./train/ordinary_bicycle_s_000035.png
# image saved to ./train/safety_bike_s_000244.png
# image saved to ./train/bicycle_s_000137.png
# image saved to ./train/motorbike_s_000331.png
# image saved to ./train/motorcycle_s_000120.png
# image saved to ./train/velocipede_s_000989.png
# image saved to ./train/moped_s_000135.png
# image saved to ./train/bicycle_s_000569.png
# image saved to ./train/safety_bicycle_s_001699.png
# image saved to ./train/bicycle_s_000399.png
# image saved to ./train/bike_s_002033.png
# image saved to ./train/ordinary_bicycle_s_000280.png
# image saved to ./train/bike_s_002283.png
# image saved to ./train/cycle_s_001413.png
# image saved to ./train/dirt_bike_s_000059.png
# image saved to ./train/motorcycle_s_001699.png
# image saved to ./train/motorcycle_s_000687.png
# image saved to ./train/bike_s_000304.png
# image saved to ./train/motorcycle_s_002192.png
# image saved to ./train/motorcycle_s_000887.png
# image saved to ./train/bike_s_002042.png
# image saved to ./train/bicycle_s_000467.png
# image saved to ./train/motorcycle_s_001706.png
# image saved to ./train/minibike_s_002176.png
# image saved to ./train/safety_bicycle_s_000760.png
# image saved to ./train/bicycle_s_000546.png
# image saved to ./train/safety_bike_s_000158.png
# image saved to ./train/bicycle_s_001679.png
# image saved to ./train/motorcycle_s_000924.png
# image saved to ./train/bicycle_s_000996.png
# image saved to ./train/motorcycle_s_000432.png
# image saved to ./train/ordinary_bicycle_s_000277.png
# image saved to ./train/bike_s_002164.png
# image saved to ./train/minibike_s_000036.png
# image saved to ./train/motorbike_s_000062.png
# image saved to ./train/motorcycle_s_000133.png
# image saved to ./train/safety_bike_s_000328.png
# image saved to ./train/safety_bicycle_s_001028.png
# image saved to ./train/minibike_s_001506.png
# image saved to ./train/motorcycle_s_001549.png
# image saved to ./train/bike_s_002292.png
# image saved to ./train/bike_s_000121.png
# image saved to ./train/motorcycle_s_001167.png
# image saved to ./train/bicycle_s_000124.png
# image saved to ./train/motorcycle_s_002237.png
# image saved to ./train/velocipede_s_001870.png
# image saved to ./train/moped_s_000119.png
# image saved to ./train/minibike_s_000121.png
# image saved to ./train/motorcycle_s_000928.png
# image saved to ./train/minibike_s_001881.png
# image saved to ./train/bike_s_000679.png
# image saved to ./train/motorcycle_s_002183.png
# image saved to ./train/bike_s_000111.png
# image saved to ./train/bike_s_001260.png
# image saved to ./train/safety_bicycle_s_000660.png
# image saved to ./train/motorcycle_s_000695.png
# image saved to ./train/safety_bicycle_s_000233.png
# image saved to ./train/motorcycle_s_000792.png
# image saved to ./train/motorcycle_s_000922.png
# image saved to ./train/bicycle_s_002711.png
# image saved to ./train/bike_s_000390.png
# image saved to ./train/minibike_s_001094.png
# image saved to ./train/minibike_s_000507.png
# image saved to ./train/motorcycle_s_001213.png
# image saved to ./train/bike_s_000154.png
# image saved to ./train/motorcycle_s_000223.png
# image saved to ./train/bicycle_s_002661.png
# image saved to ./train/safety_bicycle_s_000232.png
# image saved to ./train/bicycle_s_001663.png
# image saved to ./train/motorbike_s_000463.png
# image saved to ./train/minibike_s_002137.png
# image saved to ./train/safety_bicycle_s_001651.png
# image saved to ./train/motorcycle_s_000151.png
# image saved to ./train/motorcycle_s_000217.png
# image saved to ./train/bike_s_001877.png
# image saved to ./train/velocipede_s_001278.png
# image saved to ./train/minibike_s_001540.png
# image saved to ./train/minibike_s_001885.png
# image saved to ./train/velocipede_s_000012.png
# image saved to ./train/bicycle_s_001956.png
# image saved to ./train/ordinary_bicycle_s_000098.png
# image saved to ./train/bicycle_s_002725.png
# image saved to ./train/velocipede_s_001210.png
# image saved to ./train/bicycle_s_000039.png
# image saved to ./train/motorcycle_s_000654.png
# image saved to ./train/safety_bike_s_000079.png
# image saved to ./train/motorcycle_s_002291.png
# image saved to ./train/cycle_s_002168.png
# image saved to ./train/bike_s_001078.png
# image saved to ./train/motorbike_s_000427.png
# image saved to ./train/minibike_s_001921.png
# image saved to ./train/motorcycle_s_000917.png
# image saved to ./train/velocipede_s_001920.png
# image saved to ./train/cycle_s_003026.png
# image saved to ./train/motorcycle_s_000543.png
# image saved to ./train/minibike_s_000491.png
# image saved to ./train/motorcycle_s_001439.png
# image saved to ./train/minibike_s_002084.png
# image saved to ./train/bicycle_s_000775.png
# image saved to ./train/motorcycle_s_000262.png
# image saved to ./train/moped_s_000237.png
# image saved to ./train/bicycle_s_000978.png
# image saved to ./train/bike_s_000162.png
# image saved to ./train/motorbike_s_000106.png
# image saved to ./train/motorcycle_s_000136.png
# image saved to ./train/motorcycle_s_001319.png
# image saved to ./train/safety_bicycle_s_000125.png
# image saved to ./train/bicycle_s_001402.png
# image saved to ./train/minibike_s_000511.png
# image saved to ./train/motorcycle_s_000332.png
# image saved to ./train/motorcycle_s_001315.png
# image saved to ./train/ordinary_bicycle_s_000031.png
# image saved to ./train/motorcycle_s_000353.png
# image saved to ./train/motorcycle_s_000521.png
# image saved to ./train/safety_bicycle_s_000860.png
# image saved to ./train/motorcycle_s_002153.png
# image saved to ./train/safety_bicycle_s_000324.png
# image saved to ./train/ordinary_bicycle_s_000112.png
# image saved to ./train/motorbike_s_000068.png
# image saved to ./train/motorcycle_s_002254.png
# image saved to ./train/motorcycle_s_000989.png
# image saved to ./train/motorcycle_s_000622.png
# image saved to ./train/bike_s_000545.png
# image saved to ./train/ordinary_bicycle_s_000099.png
# image saved to ./train/safety_bike_s_001257.png
# image saved to ./train/bicycle_s_001203.png
# image saved to ./train/safety_bicycle_s_001085.png
# image saved to ./train/motorcycle_s_002222.png
# image saved to ./train/safety_bicycle_s_001639.png
# image saved to ./train/velocipede_s_001222.png
# image saved to ./train/minibike_s_000392.png
# image saved to ./train/ordinary_bicycle_s_000308.png
# image saved to ./train/motorcycle_s_001896.png
# image saved to ./train/motorcycle_s_000325.png
# image saved to ./train/bicycle_s_000986.png
# image saved to ./train/safety_bicycle_s_000373.png
# image saved to ./train/safety_bicycle_s_000348.png
# image saved to ./train/bicycle_s_002005.png
# image saved to ./train/minibike_s_002130.png
# image saved to ./train/safety_bike_s_000867.png
# image saved to ./train/bicycle_s_002475.png
# image saved to ./train/minibike_s_001193.png
# image saved to ./train/minibike_s_001366.png
# image saved to ./train/motorcycle_s_001711.png
# image saved to ./train/minibike_s_001275.png
# image saved to ./train/velocipede_s_001907.png
# image saved to ./train/motorcycle_s_000207.png
# image saved to ./train/motorcycle_s_001409.png
# image saved to ./train/safety_bicycle_s_000261.png
# image saved to ./train/minibike_s_000738.png
# image saved to ./train/motorcycle_s_001106.png
# image saved to ./train/safety_bike_s_000198.png
# image saved to ./train/minibike_s_001479.png
# image saved to ./train/velocipede_s_000430.png
# image saved to ./train/bicycle_s_001409.png
# image saved to ./train/motorcycle_s_000938.png
# image saved to ./train/motorcycle_s_000941.png
# image saved to ./train/bicycle_s_000038.png
# image saved to ./train/minibike_s_001016.png
# image saved to ./train/velocipede_s_001200.png
# image saved to ./train/bike_s_002109.png
# image saved to ./train/cycle_s_002092.png
# image saved to ./train/motorcycle_s_002066.png
# image saved to ./train/motorcycle_s_001920.png
# image saved to ./train/minibike_s_000459.png
# image saved to ./train/bicycle_s_001904.png
# image saved to ./train/minibike_s_001996.png
# image saved to ./train/motorcycle_s_001611.png
# image saved to ./train/velocipede_s_001141.png
# image saved to ./train/minibike_s_001747.png
# image saved to ./train/safety_bicycle_s_001029.png
# image saved to ./train/ordinary_bicycle_s_000029.png
# image saved to ./train/minibike_s_002163.png
# image saved to ./train/safety_bike_s_001148.png
# image saved to ./train/cycle_s_003008.png
# image saved to ./train/bicycle_s_000099.png
# image saved to ./train/minibike_s_000429.png
# image saved to ./train/bike_s_000003.png
# image saved to ./train/cycle_s_002178.png
# image saved to ./train/cycle_s_000639.png
# image saved to ./train/motorcycle_s_000734.png
# image saved to ./train/motorcycle_s_000309.png
# image saved to ./train/bicycle_s_000371.png
# image saved to ./train/minibike_s_001270.png
# image saved to ./train/minibike_s_000914.png
# image saved to ./train/moped_s_000021.png
# image saved to ./train/motorcycle_s_000242.png
# image saved to ./train/minibike_s_000314.png
# image saved to ./train/motorcycle_s_000698.png
# image saved to ./train/motorcycle_s_001360.png
# image saved to ./train/ordinary_bicycle_s_000157.png
# image saved to ./train/minibike_s_001838.png
# image saved to ./train/bicycle_s_002247.png
# image saved to ./train/motorcycle_s_000027.png
# image saved to ./train/minibike_s_000906.png
# image saved to ./train/safety_bicycle_s_000500.png
# image saved to ./train/minibike_s_002146.png
# image saved to ./train/motorcycle_s_001242.png
# image saved to ./train/motorcycle_s_001707.png
# image saved to ./train/cycle_s_003043.png
# image saved to ./train/safety_bicycle_s_001109.png
# image saved to ./train/bike_s_001131.png
# image saved to ./train/motorcycle_s_001118.png
# image saved to ./train/bike_s_001418.png
# image saved to ./train/bicycle_s_002550.png
# image saved to ./train/bicycle_s_002100.png
# image saved to ./train/motorcycle_s_000933.png
# image saved to ./train/bicycle_s_002624.png
# image saved to ./train/safety_bicycle_s_001063.png
# image saved to ./train/motorbike_s_000361.png
# image saved to ./train/safety_bicycle_s_000193.png
# image saved to ./train/safety_bicycle_s_000092.png
# image saved to ./train/motorcycle_s_000009.png
# image saved to ./train/bicycle_s_001554.png
# image saved to ./train/motorcycle_s_001297.png
# image saved to ./train/safety_bicycle_s_000296.png
# image saved to ./train/safety_bike_s_001371.png
# image saved to ./train/bicycle_s_001569.png
# image saved to ./train/motorcycle_s_001536.png
# image saved to ./train/safety_bicycle_s_001659.png
# image saved to ./train/ordinary_bicycle_s_000102.png
# image saved to ./train/bike_s_002215.png
# image saved to ./train/bicycle_s_002410.png
# image saved to ./train/cycle_s_003147.png
# image saved to ./train/bicycle_s_002759.png
# image saved to ./train/minibike_s_000335.png
# image saved to ./train/safety_bike_s_000848.png
# image saved to ./train/velocipede_s_000807.png
# image saved to ./train/bike_s_000024.png
# image saved to ./train/minibike_s_000435.png
# image saved to ./train/minibike_s_001498.png
# image saved to ./train/velocipede_s_001166.png
# image saved to ./train/motorcycle_s_001012.png
# image saved to ./train/velocipede_s_000330.png
# image saved to ./train/motorcycle_s_000032.png
# image saved to ./train/minibike_s_001597.png
# image saved to ./train/motorcycle_s_002298.png
# image saved to ./train/minibike_s_000102.png
# image saved to ./train/motorcycle_s_001507.png
# image saved to ./train/motorbike_s_000022.png
# image saved to ./train/motorcycle_s_000594.png
# image saved to ./train/minibike_s_001539.png
# image saved to ./train/bicycle_s_001228.png
# image saved to ./train/minibike_s_001344.png
# image saved to ./train/motorcycle_s_002271.png
# image saved to ./train/motorcycle_s_000791.png
# image saved to ./train/ordinary_bicycle_s_000218.png
# image saved to ./train/motorcycle_s_000221.png
# image saved to ./train/minibike_s_001691.png
# image saved to ./train/motorcycle_s_001209.png
# image saved to ./train/ordinary_bicycle_s_000101.png
# image saved to ./train/motorcycle_s_001326.png
# image saved to ./train/minibike_s_001249.png
# image saved to ./train/bicycle_s_000408.png
# image saved to ./train/minibike_s_000520.png
# image saved to ./train/minibike_s_002218.png
# image saved to ./train/minibike_s_001458.png
# image saved to ./train/moped_s_000034.png
# image saved to ./train/motorbike_s_000119.png
# image saved to ./train/motorcycle_s_001027.png
# image saved to ./train/cycle_s_001477.png
# image saved to ./train/motorcycle_s_001710.png
# image saved to ./train/minibike_s_000434.png
# image saved to ./train/motorcycle_s_000979.png
# image saved to ./train/safety_bike_s_001289.png
# image saved to ./train/safety_bike_s_001560.png
# image saved to ./train/minibike_s_000011.png
# image saved to ./train/bicycle_s_001642.png
# image saved to ./train/minibike_s_000527.png
# image saved to ./train/bicycle_s_001245.png
# image saved to ./train/bike_s_000934.png
# image saved to ./train/velocipede_s_001244.png
# image saved to ./train/velocipede_s_001882.png
# image saved to ./train/bike_s_001683.png
# image saved to ./train/minibike_s_000127.png
# image saved to ./train/bicycle_s_001002.png
# image saved to ./train/moped_s_000044.png
# image saved to ./train/bike_s_000025.png
# image saved to ./train/minibike_s_000690.png
# image saved to ./train/minibike_s_000022.png
# image saved to ./train/motorcycle_s_001196.png
# image saved to ./train/ordinary_bicycle_s_000269.png
# image saved to ./train/cycle_s_002503.png
# image saved to ./train/ordinary_bicycle_s_000097.png
# image saved to ./train/safety_bike_s_000009.png
# image saved to ./train/safety_bike_s_000015.png
# image saved to ./train/minibike_s_000613.png
# image saved to ./train/motorcycle_s_001017.png
# image saved to ./train/minibike_s_000203.png
# image saved to ./train/velocipede_s_001489.png
# image saved to ./train/minibike_s_000813.png
# image saved to ./train/safety_bicycle_s_000425.png
# image saved to ./train/motorcycle_s_001622.png
# image saved to ./train/motorcycle_s_000593.png
# image saved to ./train/minibike_s_000116.png
# image saved to ./train/motorcycle_s_001563.png
# image saved to ./train/cycle_s_001875.png
# image saved to ./train/safety_bike_s_001590.png
# image saved to ./train/minibike_s_000830.png
# image saved to ./train/minibike_s_000570.png
# image saved to ./train/bike_s_001380.png
# image saved to ./train/moped_s_000236.png
# image saved to ./train/motorcycle_s_000339.png
# image saved to ./train/safety_bike_s_001465.png
# image saved to ./train/motorcycle_s_001714.png
# image saved to ./train/minibike_s_001191.png
# image saved to ./train/cycle_s_002882.png
# image saved to ./train/bicycle_s_000822.png
# image saved to ./train/bike_s_001827.png
# image saved to ./train/ordinary_bicycle_s_000110.png
# image saved to ./train/minibike_s_000293.png
# image saved to ./train/motorcycle_s_000249.png
# image saved to ./train/ordinary_bicycle_s_000154.png
# image saved to ./train/motorcycle_s_001527.png
# image saved to ./train/motorcycle_s_001033.png
# image saved to ./train/motorcycle_s_001709.png
# image saved to ./train/bicycle_s_001348.png
# image saved to ./train/minibike_s_002194.png
# image saved to ./train/minibike_s_001079.png
# image saved to ./train/bicycle_s_000017.png
# image saved to ./train/minibike_s_001638.png
# image saved to ./train/motorcycle_s_001587.png
# image saved to ./train/motorcycle_s_000486.png
# image saved to ./train/minibike_s_001880.png
# image saved to ./train/dirt_bike_s_000003.png
# image saved to ./train/bike_s_000336.png
# image saved to ./train/minibike_s_002115.png
# image saved to ./train/motorbike_s_000449.png
# image saved to ./train/motorcycle_s_000304.png
# image saved to ./train/motorcycle_s_000022.png
# image saved to ./train/motorcycle_s_001623.png
# image saved to ./train/motorbike_s_000223.png
# image saved to ./train/motorcycle_s_000290.png
# image saved to ./train/safety_bicycle_s_001327.png
# image saved to ./train/bike_s_002288.png
# image saved to ./train/minibike_s_000569.png
# image saved to ./train/bike_s_002047.png
# image saved to ./train/motorcycle_s_002031.png
# image saved to ./train/bike_s_000062.png
# image saved to ./train/cycle_s_000871.png
# image saved to ./train/motorcycle_s_001778.png
# image saved to ./train/velocipede_s_000010.png
# image saved to ./train/motorcycle_s_001247.png
# image saved to ./train/motorcycle_s_000724.png
# image saved to ./train/velocipede_s_001637.png
# image saved to ./train/motorcycle_s_000291.png
# image saved to ./test/safety_bike_s_000390.png
# image saved to ./test/bike_s_000658.png
# image saved to ./test/velocipede_s_001744.png
# image saved to ./test/bike_s_000643.png
# image saved to ./test/ordinary_bicycle_s_000437.png
# image saved to ./test/motorcycle_s_000323.png
# image saved to ./test/safety_bike_s_001253.png
# image saved to ./test/cycle_s_001306.png
# image saved to ./test/velocipede_s_000863.png
# image saved to ./test/bicycle_s_000479.png
# image saved to ./test/minibike_s_002173.png
# image saved to ./test/motorcycle_s_000352.png
# image saved to ./test/bike_s_000801.png
# image saved to ./test/motorbike_s_000433.png
# image saved to ./test/bike_s_001068.png
# image saved to ./test/motorcycle_s_000963.png
# image saved to ./test/bike_s_001852.png
# image saved to ./test/motorcycle_s_000139.png
# image saved to ./test/motorbike_s_000465.png
# image saved to ./test/bicycle_s_000513.png
# image saved to ./test/cycle_s_002305.png
# image saved to ./test/motorcycle_s_000615.png
# image saved to ./test/moped_s_000306.png
# image saved to ./test/minibike_s_000052.png
# image saved to ./test/bike_s_001342.png
# image saved to ./test/cycle_s_001297.png
# image saved to ./test/motorcycle_s_001955.png
# image saved to ./test/cycle_s_001953.png
# image saved to ./test/motorcycle_s_000494.png
# image saved to ./test/motorcycle_s_001249.png
# image saved to ./test/velocipede_s_000292.png
# image saved to ./test/minibike_s_001651.png
# image saved to ./test/bicycle_s_001102.png
# image saved to ./test/safety_bike_s_001132.png
# image saved to ./test/moped_s_000007.png
# image saved to ./test/motorcycle_s_000211.png
# image saved to ./test/cycle_s_000970.png
# image saved to ./test/motorcycle_s_002126.png
# image saved to ./test/minibike_s_001732.png
# image saved to ./test/minibike_s_001867.png
# image saved to ./test/minibike_s_002227.png
# image saved to ./test/cycle_s_000068.png
# image saved to ./test/minibike_s_000880.png
# image saved to ./test/moped_s_000033.png
# image saved to ./test/bicycle_s_001107.png
# image saved to ./test/bike_s_002116.png
# image saved to ./test/bike_s_001738.png
# image saved to ./test/bike_s_002009.png
# image saved to ./test/minibike_s_000947.png
# image saved to ./test/bike_s_001159.png
# image saved to ./test/safety_bike_s_001065.png
# image saved to ./test/motorbike_s_000005.png
# image saved to ./test/minibike_s_000075.png
# image saved to ./test/motorcycle_s_001164.png
# image saved to ./test/motorcycle_s_000679.png
# image saved to ./test/motorcycle_s_001892.png
# image saved to ./test/bike_s_000694.png
# image saved to ./test/velocipede_s_000106.png
# image saved to ./test/velocipede_s_000001.png
# image saved to ./test/motorcycle_s_002177.png
# image saved to ./test/motorbike_s_000126.png
# image saved to ./test/safety_bicycle_s_001286.png
# image saved to ./test/motorcycle_s_001936.png
# image saved to ./test/safety_bike_s_001087.png
# image saved to ./test/cycle_s_001648.png
# image saved to ./test/minibike_s_000801.png
# image saved to ./test/motorcycle_s_000427.png
# image saved to ./test/minibike_s_001089.png
# image saved to ./test/motorcycle_s_000530.png
# image saved to ./test/velocipede_s_001232.png
# image saved to ./test/motorcycle_s_001261.png
# image saved to ./test/velocipede_s_001466.png
# image saved to ./test/motorcycle_s_001269.png
# image saved to ./test/bicycle_s_000776.png
# image saved to ./test/motorcycle_s_001348.png
# image saved to ./test/motorcycle_s_002026.png
# image saved to ./test/safety_bike_s_000540.png
# image saved to ./test/safety_bicycle_s_000280.png
# image saved to ./test/bike_s_000131.png
# image saved to ./test/cycle_s_000010.png
# image saved to ./test/minibike_s_000828.png
# image saved to ./test/minibike_s_000288.png
# image saved to ./test/velocipede_s_001355.png
# image saved to ./test/safety_bicycle_s_001575.png
# image saved to ./test/safety_bike_s_001690.png
# image saved to ./test/cycle_s_001044.png
# image saved to ./test/motorcycle_s_000063.png
# image saved to ./test/velocipede_s_001379.png
# image saved to ./test/minibike_s_001441.png
# image saved to ./test/motorcycle_s_000797.png
# image saved to ./test/velocipede_s_001790.png
# image saved to ./test/motorbike_s_000135.png
# image saved to ./test/cycle_s_002613.png
# image saved to ./test/motorcycle_s_001960.png
# image saved to ./test/minibike_s_000913.png
# image saved to ./test/motorcycle_s_000685.png
# image saved to ./test/ordinary_bicycle_s_000431.png
# image saved to ./test/minibike_s_002051.png
# image saved to ./test/motorcycle_s_000446.png
# image saved to ./test/velocipede_s_001699.png
# image saved to ./test/minibike_s_000792.png
# image saved to ./test/bicycle_s_002458.png
# image saved to ./test/minibike_s_000505.png
# image saved to ./test/minibike_s_000573.png
# image saved to ./test/velocipede_s_000369.png
# image saved to ./test/moped_s_000064.png
# image saved to ./test/minibike_s_001893.png
# image saved to ./test/motorcycle_s_000878.png
# image saved to ./test/motorcycle_s_000042.png
# image saved to ./test/motorcycle_s_000606.png
# image saved to ./test/minibike_s_002230.png
# image saved to ./test/motorcycle_s_001519.png
# image saved to ./test/motorcycle_s_000512.png
# image saved to ./test/cycle_s_001915.png
# image saved to ./test/safety_bike_s_000541.png
# image saved to ./test/safety_bike_s_000192.png
# image saved to ./test/bicycle_s_000030.png
# image saved to ./test/motorcycle_s_001385.png
# image saved to ./test/minibike_s_000960.png
# image saved to ./test/safety_bike_s_000791.png
# image saved to ./test/bike_s_000071.png
# image saved to ./test/motorcycle_s_000876.png
# image saved to ./test/ordinary_bicycle_s_000350.png
# image saved to ./test/motorcycle_s_000602.png
# image saved to ./test/motorcycle_s_000222.png
# image saved to ./test/minibike_s_000309.png
# image saved to ./test/motorcycle_s_001679.png
# image saved to ./test/minibike_s_001473.png
# image saved to ./test/velocipede_s_001633.png
# image saved to ./test/safety_bike_s_000438.png
# image saved to ./test/safety_bicycle_s_000315.png
# image saved to ./test/motorcycle_s_002112.png
# image saved to ./test/bike_s_000163.png
# image saved to ./test/bicycle_s_000059.png
# image saved to ./test/bicycle_s_001789.png
# image saved to ./test/safety_bike_s_000699.png
# image saved to ./test/motorbike_s_000324.png
# image saved to ./test/motorcycle_s_000485.png
# image saved to ./test/motorcycle_s_001687.png
# image saved to ./test/minibike_s_000497.png
# image saved to ./test/minibike_s_001547.png
# image saved to ./test/minibike_s_000055.png
# image saved to ./test/ordinary_bicycle_s_000169.png
# image saved to ./test/minibike_s_000290.png
# image saved to ./test/velocipede_s_001335.png
# image saved to ./test/bicycle_s_001804.png
# image saved to ./test/safety_bike_s_000488.png
# image saved to ./test/bike_s_001216.png
# image saved to ./test/motorbike_s_000121.png
# image saved to ./test/bike_s_001073.png
# image saved to ./test/safety_bicycle_s_001153.png
# image saved to ./test/motorcycle_s_000171.png
# image saved to ./test/velocipede_s_000041.png
# image saved to ./test/motorcycle_s_001782.png
# image saved to ./test/motorbike_s_000629.png
# image saved to ./test/bicycle_s_000977.png
# image saved to ./test/motorcycle_s_001906.png
# image saved to ./test/bike_s_002208.png
# image saved to ./test/minibike_s_000254.png
# image saved to ./test/safety_bicycle_s_001322.png
# image saved to ./test/bike_s_000041.png
# image saved to ./test/bicycle_s_000031.png
# image saved to ./test/bicycle_s_000779.png
# image saved to ./test/velocipede_s_001277.png
# image saved to ./test/safety_bike_s_001088.png
# image saved to ./test/motorcycle_s_001971.png
# image saved to ./test/bike_s_001784.png
# image saved to ./test/motorcycle_s_000825.png
# image saved to ./test/dirt_bike_s_000001.png
# image saved to ./test/cycle_s_001214.png
# image saved to ./test/cycle_s_002964.png
# image saved to ./test/ordinary_bicycle_s_000284.png
# image saved to ./test/bicycle_s_002735.png
# image saved to ./test/motorcycle_s_000450.png
# image saved to ./test/motorcycle_s_000049.png
# image saved to ./test/motorcycle_s_000866.png
# image saved to ./test/velocipede_s_001201.png
# image saved to ./test/bike_s_000457.png
# image saved to ./test/bike_s_000330.png
# image saved to ./test/minibike_s_001605.png
# image saved to ./test/minibike_s_000398.png
# image saved to ./test/motorcycle_s_000007.png
# image saved to ./test/motorcycle_s_000040.png
# image saved to ./test/motorcycle_s_000739.png
# image saved to ./test/motorbike_s_000333.png
# image saved to ./test/safety_bike_s_001481.png
# image saved to ./test/ordinary_bicycle_s_000158.png
# image saved to ./test/motorcycle_s_001508.png
# image saved to ./test/motorcycle_s_000060.png
# image saved to ./test/cycle_s_002661.png
# image saved to ./test/bicycle_s_001047.png
# image saved to ./test/bicycle_s_000777.png
# image saved to ./test/safety_bicycle_s_000235.png
# image saved to ./test/bike_s_000487.png
# image saved to ./test/ordinary_bicycle_s_000113.png
# image saved to ./test/trail_bike_s_000073.png
# image saved to ./test/bike_s_000941.png
# image saved to ./test/motorcycle_s_000141.png
# image saved to ./test/ordinary_bicycle_s_000105.png
# image saved to ./test/bicycle_s_001218.png

# %% [markdown]
# ### 3. Load the data
#
# Now we can load the data into S3.
#
# Using the sagemaker SDK grab the current region, execution role, and bucket.

# %%
import sagemaker


bucket = 'ml-etl-project'
print("Default Bucket: {}".format(bucket))

region = 'us-east-1'
print("AWS Region: {}".format(region))

role = 'AmazonSageMaker-ExecutionRole-20250123T153605'
print("RoleArn: {}".format(role))
# Out:
# /home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages/pydantic/_internal/_fields.py:192: UserWarning: Field name "json" in "MonitoringDatasetFormat" shadows an attribute in parent "Base"
#   warnings.warn(
# [02/13/25 20:55:08] INFO     Found credentials from IAM Role:                                   ]8;id=597250;file:///home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages/botocore/credentials.py\credentials.py]8;;\:]8;id=339759;file:///home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages/botocore/credentials.py#1075\1075]8;;\
#                              BaseNotebookInstanceEc2InstanceRole
# sagemaker.config INFO - Not applying SDK defaults from location: /etc/xdg/sagemaker/config.yaml
# sagemaker.config INFO - Not applying SDK defaults from location: /home/ec2-user/.config/sagemaker/config.yaml
# Default Bucket: ml-etl-project
# AWS Region: us-east-1
# RoleArn: AmazonSageMaker-ExecutionRole-20250123T153605

# %% [markdown]
# With this data we can easily sync your data up into S3!

# %%
import os

os.environ["DEFAULT_S3_BUCKET"] = bucket
# !aws s3 sync ./train s3://${DEFAULT_S3_BUCKET}/train/
# !aws s3 sync ./test s3://${DEFAULT_S3_BUCKET}/test/
# Out:
# upload: train/bicycle_s_000017.png to s3://ml-etl-project/train/bicycle_s_000017.png
# upload: train/bicycle_s_000043.png to s3://ml-etl-project/train/bicycle_s_000043.png
# upload: train/bicycle_s_000038.png to s3://ml-etl-project/train/bicycle_s_000038.png
# upload: train/bicycle_s_000021.png to s3://ml-etl-project/train/bicycle_s_000021.png
# upload: train/bicycle_s_000035.png to s3://ml-etl-project/train/bicycle_s_000035.png
# upload: train/bicycle_s_000071.png to s3://ml-etl-project/train/bicycle_s_000071.png
# upload: train/bicycle_s_000099.png to s3://ml-etl-project/train/bicycle_s_000099.png
# upload: train/bicycle_s_000039.png to s3://ml-etl-project/train/bicycle_s_000039.png
# upload: train/bicycle_s_000051.png to s3://ml-etl-project/train/bicycle_s_000051.png
# upload: train/bicycle_s_000180.png to s3://ml-etl-project/train/bicycle_s_000180.png
# upload: train/bicycle_s_000137.png to s3://ml-etl-project/train/bicycle_s_000137.png
# upload: train/bicycle_s_000243.png to s3://ml-etl-project/train/bicycle_s_000243.png
# upload: train/bicycle_s_000282.png to s3://ml-etl-project/train/bicycle_s_000282.png
# upload: train/bicycle_s_000066.png to s3://ml-etl-project/train/bicycle_s_000066.png
# upload: train/bicycle_s_000147.png to s3://ml-etl-project/train/bicycle_s_000147.png
# upload: train/bicycle_s_000124.png to s3://ml-etl-project/train/bicycle_s_000124.png
# upload: train/bicycle_s_000371.png to s3://ml-etl-project/train/bicycle_s_000371.png
# upload: train/bicycle_s_000314.png to s3://ml-etl-project/train/bicycle_s_000314.png
# upload: train/bicycle_s_000149.png to s3://ml-etl-project/train/bicycle_s_000149.png
# upload: train/bicycle_s_000235.png to s3://ml-etl-project/train/bicycle_s_000235.png
# upload: train/bicycle_s_000392.png to s3://ml-etl-project/train/bicycle_s_000392.png
# upload: train/bicycle_s_000159.png to s3://ml-etl-project/train/bicycle_s_000159.png
# upload: train/bicycle_s_000369.png to s3://ml-etl-project/train/bicycle_s_000369.png
# upload: train/bicycle_s_000231.png to s3://ml-etl-project/train/bicycle_s_000231.png
# upload: train/bicycle_s_000399.png to s3://ml-etl-project/train/bicycle_s_000399.png
# upload: train/bicycle_s_000396.png to s3://ml-etl-project/train/bicycle_s_000396.png
# upload: train/bicycle_s_000408.png to s3://ml-etl-project/train/bicycle_s_000408.png
# upload: train/bicycle_s_000467.png to s3://ml-etl-project/train/bicycle_s_000467.png
# upload: train/bicycle_s_000463.png to s3://ml-etl-project/train/bicycle_s_000463.png
# upload: train/bicycle_s_000435.png to s3://ml-etl-project/train/bicycle_s_000435.png
# upload: train/bicycle_s_000491.png to s3://ml-etl-project/train/bicycle_s_000491.png
# upload: train/bicycle_s_000279.png to s3://ml-etl-project/train/bicycle_s_000279.png
# upload: train/bicycle_s_000522.png to s3://ml-etl-project/train/bicycle_s_000522.png
# upload: train/bicycle_s_000561.png to s3://ml-etl-project/train/bicycle_s_000561.png
# upload: train/bicycle_s_000723.png to s3://ml-etl-project/train/bicycle_s_000723.png
# upload: train/bicycle_s_000569.png to s3://ml-etl-project/train/bicycle_s_000569.png
# upload: train/bicycle_s_000156.png to s3://ml-etl-project/train/bicycle_s_000156.png
# upload: train/bicycle_s_000667.png to s3://ml-etl-project/train/bicycle_s_000667.png
# upload: train/bicycle_s_000437.png to s3://ml-etl-project/train/bicycle_s_000437.png
# upload: train/bicycle_s_000536.png to s3://ml-etl-project/train/bicycle_s_000536.png
# upload: train/bicycle_s_000537.png to s3://ml-etl-project/train/bicycle_s_000537.png
# upload: train/bicycle_s_000546.png to s3://ml-etl-project/train/bicycle_s_000546.png
# upload: train/bicycle_s_000753.png to s3://ml-etl-project/train/bicycle_s_000753.png
# upload: train/bicycle_s_000668.png to s3://ml-etl-project/train/bicycle_s_000668.png
# upload: train/bicycle_s_000778.png to s3://ml-etl-project/train/bicycle_s_000778.png
# upload: train/bicycle_s_000822.png to s3://ml-etl-project/train/bicycle_s_000822.png
# upload: train/bicycle_s_000759.png to s3://ml-etl-project/train/bicycle_s_000759.png
# upload: train/bicycle_s_000861.png to s3://ml-etl-project/train/bicycle_s_000861.png
# upload: train/bicycle_s_000781.png to s3://ml-etl-project/train/bicycle_s_000781.png
# upload: train/bicycle_s_000774.png to s3://ml-etl-project/train/bicycle_s_000774.png
# upload: train/bicycle_s_000782.png to s3://ml-etl-project/train/bicycle_s_000782.png
# upload: train/bicycle_s_000829.png to s3://ml-etl-project/train/bicycle_s_000829.png
# upload: train/bicycle_s_000775.png to s3://ml-etl-project/train/bicycle_s_000775.png
# upload: train/bicycle_s_000785.png to s3://ml-etl-project/train/bicycle_s_000785.png
# upload: train/bicycle_s_001174.png to s3://ml-etl-project/train/bicycle_s_001174.png
# upload: train/bicycle_s_000951.png to s3://ml-etl-project/train/bicycle_s_000951.png
# upload: train/bicycle_s_001203.png to s3://ml-etl-project/train/bicycle_s_001203.png
# upload: train/bicycle_s_000986.png to s3://ml-etl-project/train/bicycle_s_000986.png
# upload: train/bicycle_s_000978.png to s3://ml-etl-project/train/bicycle_s_000978.png
# upload: train/bicycle_s_000996.png to s3://ml-etl-project/train/bicycle_s_000996.png
# upload: train/bicycle_s_001111.png to s3://ml-etl-project/train/bicycle_s_001111.png
# upload: train/bicycle_s_001002.png to s3://ml-etl-project/train/bicycle_s_001002.png
# upload: train/bicycle_s_001205.png to s3://ml-etl-project/train/bicycle_s_001205.png
# upload: train/bicycle_s_001228.png to s3://ml-etl-project/train/bicycle_s_001228.png
# upload: train/bicycle_s_001247.png to s3://ml-etl-project/train/bicycle_s_001247.png
# upload: train/bicycle_s_001245.png to s3://ml-etl-project/train/bicycle_s_001245.png
# upload: train/bicycle_s_001409.png to s3://ml-etl-project/train/bicycle_s_001409.png
# upload: train/bicycle_s_001402.png to s3://ml-etl-project/train/bicycle_s_001402.png
# upload: train/bicycle_s_001348.png to s3://ml-etl-project/train/bicycle_s_001348.png
# upload: train/bicycle_s_001168.png to s3://ml-etl-project/train/bicycle_s_001168.png
# upload: train/bicycle_s_001411.png to s3://ml-etl-project/train/bicycle_s_001411.png
# upload: train/bicycle_s_001388.png to s3://ml-etl-project/train/bicycle_s_001388.png
# upload: train/bicycle_s_001338.png to s3://ml-etl-project/train/bicycle_s_001338.png
# upload: train/bicycle_s_001569.png to s3://ml-etl-project/train/bicycle_s_001569.png
# upload: train/bicycle_s_001452.png to s3://ml-etl-project/train/bicycle_s_001452.png
# upload: train/bicycle_s_001663.png to s3://ml-etl-project/train/bicycle_s_001663.png
# upload: train/bicycle_s_001583.png to s3://ml-etl-project/train/bicycle_s_001583.png
# upload: train/bicycle_s_001554.png to s3://ml-etl-project/train/bicycle_s_001554.png
# upload: train/bicycle_s_001642.png to s3://ml-etl-project/train/bicycle_s_001642.png
# upload: train/bicycle_s_001679.png to s3://ml-etl-project/train/bicycle_s_001679.png
# upload: train/bicycle_s_001470.png to s3://ml-etl-project/train/bicycle_s_001470.png
# upload: train/bicycle_s_001448.png to s3://ml-etl-project/train/bicycle_s_001448.png
# upload: train/bicycle_s_001673.png to s3://ml-etl-project/train/bicycle_s_001673.png
# upload: train/bicycle_s_001688.png to s3://ml-etl-project/train/bicycle_s_001688.png
# upload: train/bicycle_s_001681.png to s3://ml-etl-project/train/bicycle_s_001681.png
# upload: train/bicycle_s_001928.png to s3://ml-etl-project/train/bicycle_s_001928.png
# upload: train/bicycle_s_001814.png to s3://ml-etl-project/train/bicycle_s_001814.png
# upload: train/bicycle_s_001904.png to s3://ml-etl-project/train/bicycle_s_001904.png
# upload: train/bicycle_s_001956.png to s3://ml-etl-project/train/bicycle_s_001956.png
# upload: train/bicycle_s_001748.png to s3://ml-etl-project/train/bicycle_s_001748.png
# upload: train/bicycle_s_001687.png to s3://ml-etl-project/train/bicycle_s_001687.png
# upload: train/bicycle_s_001693.png to s3://ml-etl-project/train/bicycle_s_001693.png
# upload: train/bicycle_s_001757.png to s3://ml-etl-project/train/bicycle_s_001757.png
# upload: train/bicycle_s_002218.png to s3://ml-etl-project/train/bicycle_s_002218.png
# upload: train/bicycle_s_002153.png to s3://ml-etl-project/train/bicycle_s_002153.png
# upload: train/bicycle_s_002100.png to s3://ml-etl-project/train/bicycle_s_002100.png
# upload: train/bicycle_s_002029.png to s3://ml-etl-project/train/bicycle_s_002029.png
# upload: train/bicycle_s_002237.png to s3://ml-etl-project/train/bicycle_s_002237.png
# upload: train/bicycle_s_002005.png to s3://ml-etl-project/train/bicycle_s_002005.png
# upload: train/bicycle_s_002012.png to s3://ml-etl-project/train/bicycle_s_002012.png
# upload: train/bicycle_s_002049.png to s3://ml-etl-project/train/bicycle_s_002049.png
# upload: train/bicycle_s_002129.png to s3://ml-etl-project/train/bicycle_s_002129.png
# upload: train/bicycle_s_002132.png to s3://ml-etl-project/train/bicycle_s_002132.png
# upload: train/bicycle_s_002247.png to s3://ml-etl-project/train/bicycle_s_002247.png
# upload: train/bicycle_s_002299.png to s3://ml-etl-project/train/bicycle_s_002299.png
# upload: train/bicycle_s_002258.png to s3://ml-etl-project/train/bicycle_s_002258.png
# upload: train/bicycle_s_002374.png to s3://ml-etl-project/train/bicycle_s_002374.png
# upload: train/bicycle_s_002410.png to s3://ml-etl-project/train/bicycle_s_002410.png
# upload: train/bicycle_s_002400.png to s3://ml-etl-project/train/bicycle_s_002400.png
# upload: train/bicycle_s_002222.png to s3://ml-etl-project/train/bicycle_s_002222.png
# upload: train/bicycle_s_002338.png to s3://ml-etl-project/train/bicycle_s_002338.png
# upload: train/bicycle_s_002550.png to s3://ml-etl-project/train/bicycle_s_002550.png
# upload: train/bicycle_s_002436.png to s3://ml-etl-project/train/bicycle_s_002436.png
# upload: train/bicycle_s_002661.png to s3://ml-etl-project/train/bicycle_s_002661.png
# upload: train/bicycle_s_002448.png to s3://ml-etl-project/train/bicycle_s_002448.png
# upload: train/bicycle_s_002373.png to s3://ml-etl-project/train/bicycle_s_002373.png
# upload: train/bicycle_s_002669.png to s3://ml-etl-project/train/bicycle_s_002669.png
# upload: train/bicycle_s_002624.png to s3://ml-etl-project/train/bicycle_s_002624.png
# upload: train/bicycle_s_002475.png to s3://ml-etl-project/train/bicycle_s_002475.png
# upload: train/bicycle_s_002725.png to s3://ml-etl-project/train/bicycle_s_002725.png
# upload: train/bicycle_s_002569.png to s3://ml-etl-project/train/bicycle_s_002569.png
# upload: train/bicycle_s_002521.png to s3://ml-etl-project/train/bicycle_s_002521.png
# upload: train/bicycle_s_002715.png to s3://ml-etl-project/train/bicycle_s_002715.png
# upload: train/bicycle_s_002728.png to s3://ml-etl-project/train/bicycle_s_002728.png
# upload: train/bicycle_s_002711.png to s3://ml-etl-project/train/bicycle_s_002711.png
# upload: train/bicycle_s_002762.png to s3://ml-etl-project/train/bicycle_s_002762.png
# upload: train/bike_s_000015.png to s3://ml-etl-project/train/bike_s_000015.png
# upload: train/bike_s_000003.png to s3://ml-etl-project/train/bike_s_000003.png
# upload: train/bicycle_s_002759.png to s3://ml-etl-project/train/bicycle_s_002759.png
# upload: train/bicycle_s_002729.png to s3://ml-etl-project/train/bicycle_s_002729.png
# upload: train/bike_s_000021.png to s3://ml-etl-project/train/bike_s_000021.png
# upload: train/bike_s_000023.png to s3://ml-etl-project/train/bike_s_000023.png
# upload: train/bike_s_000001.png to s3://ml-etl-project/train/bike_s_000001.png
# upload: train/bike_s_000025.png to s3://ml-etl-project/train/bike_s_000025.png
# upload: train/bike_s_000024.png to s3://ml-etl-project/train/bike_s_000024.png
# upload: train/bike_s_000035.png to s3://ml-etl-project/train/bike_s_000035.png
# upload: train/bike_s_000018.png to s3://ml-etl-project/train/bike_s_000018.png
# upload: train/bike_s_000040.png to s3://ml-etl-project/train/bike_s_000040.png
# upload: train/bike_s_000062.png to s3://ml-etl-project/train/bike_s_000062.png
# upload: train/bike_s_000026.png to s3://ml-etl-project/train/bike_s_000026.png
# upload: train/bike_s_000034.png to s3://ml-etl-project/train/bike_s_000034.png
# upload: train/bike_s_000051.png to s3://ml-etl-project/train/bike_s_000051.png
# upload: train/bike_s_000111.png to s3://ml-etl-project/train/bike_s_000111.png
# upload: train/bike_s_000005.png to s3://ml-etl-project/train/bike_s_000005.png
# upload: train/bike_s_000204.png to s3://ml-etl-project/train/bike_s_000204.png
# upload: train/bike_s_000256.png to s3://ml-etl-project/train/bike_s_000256.png
# upload: train/bike_s_000129.png to s3://ml-etl-project/train/bike_s_000129.png
# upload: train/bike_s_000154.png to s3://ml-etl-project/train/bike_s_000154.png
# upload: train/bike_s_000299.png to s3://ml-etl-project/train/bike_s_000299.png
# upload: train/bike_s_000302.png to s3://ml-etl-project/train/bike_s_000302.png
# upload: train/bike_s_000127.png to s3://ml-etl-project/train/bike_s_000127.png
# upload: train/bike_s_000237.png to s3://ml-etl-project/train/bike_s_000237.png
# upload: train/bike_s_000336.png to s3://ml-etl-project/train/bike_s_000336.png
# upload: train/bike_s_000390.png to s3://ml-etl-project/train/bike_s_000390.png
# upload: train/bike_s_000304.png to s3://ml-etl-project/train/bike_s_000304.png
# upload: train/bike_s_000364.png to s3://ml-etl-project/train/bike_s_000364.png
# upload: train/bike_s_000397.png to s3://ml-etl-project/train/bike_s_000397.png
# upload: train/bike_s_000392.png to s3://ml-etl-project/train/bike_s_000392.png
# upload: train/bike_s_000164.png to s3://ml-etl-project/train/bike_s_000164.png
# upload: train/bike_s_000162.png to s3://ml-etl-project/train/bike_s_000162.png
# upload: train/bike_s_000121.png to s3://ml-etl-project/train/bike_s_000121.png
# upload: train/bike_s_000555.png to s3://ml-etl-project/train/bike_s_000555.png
# upload: train/bike_s_000516.png to s3://ml-etl-project/train/bike_s_000516.png
# upload: train/bike_s_000522.png to s3://ml-etl-project/train/bike_s_000522.png
# upload: train/bike_s_000544.png to s3://ml-etl-project/train/bike_s_000544.png
# upload: train/bike_s_000506.png to s3://ml-etl-project/train/bike_s_000506.png
# upload: train/bike_s_000593.png to s3://ml-etl-project/train/bike_s_000593.png
# upload: train/bike_s_000545.png to s3://ml-etl-project/train/bike_s_000545.png
# upload: train/bike_s_000657.png to s3://ml-etl-project/train/bike_s_000657.png
# upload: train/bike_s_000474.png to s3://ml-etl-project/train/bike_s_000474.png
# upload: train/bike_s_000628.png to s3://ml-etl-project/train/bike_s_000628.png
# upload: train/bike_s_000679.png to s3://ml-etl-project/train/bike_s_000679.png
# upload: train/bike_s_000934.png to s3://ml-etl-project/train/bike_s_000934.png
# upload: train/bike_s_000722.png to s3://ml-etl-project/train/bike_s_000722.png
# upload: train/bike_s_000990.png to s3://ml-etl-project/train/bike_s_000990.png
# upload: train/bike_s_000682.png to s3://ml-etl-project/train/bike_s_000682.png
# upload: train/bike_s_001078.png to s3://ml-etl-project/train/bike_s_001078.png
# upload: train/bike_s_001072.png to s3://ml-etl-project/train/bike_s_001072.png
# upload: train/bike_s_001200.png to s3://ml-etl-project/train/bike_s_001200.png
# upload: train/bike_s_001093.png to s3://ml-etl-project/train/bike_s_001093.png
# upload: train/bike_s_000926.png to s3://ml-etl-project/train/bike_s_000926.png
# upload: train/bike_s_000855.png to s3://ml-etl-project/train/bike_s_000855.png
# upload: train/bike_s_001226.png to s3://ml-etl-project/train/bike_s_001226.png
# upload: train/bike_s_001116.png to s3://ml-etl-project/train/bike_s_001116.png
# upload: train/bike_s_001131.png to s3://ml-etl-project/train/bike_s_001131.png
# upload: train/bike_s_001113.png to s3://ml-etl-project/train/bike_s_001113.png
# upload: train/bike_s_001027.png to s3://ml-etl-project/train/bike_s_001027.png
# upload: train/bike_s_001320.png to s3://ml-etl-project/train/bike_s_001320.png
# upload: train/bike_s_001260.png to s3://ml-etl-project/train/bike_s_001260.png
# upload: train/bike_s_001380.png to s3://ml-etl-project/train/bike_s_001380.png
# upload: train/bike_s_001517.png to s3://ml-etl-project/train/bike_s_001517.png
# upload: train/bike_s_001418.png to s3://ml-etl-project/train/bike_s_001418.png
# upload: train/bike_s_001519.png to s3://ml-etl-project/train/bike_s_001519.png
# upload: train/bike_s_001613.png to s3://ml-etl-project/train/bike_s_001613.png
# upload: train/bike_s_001592.png to s3://ml-etl-project/train/bike_s_001592.png
# upload: train/bike_s_001415.png to s3://ml-etl-project/train/bike_s_001415.png
# upload: train/bike_s_001462.png to s3://ml-etl-project/train/bike_s_001462.png
# upload: train/bike_s_001572.png to s3://ml-etl-project/train/bike_s_001572.png
# upload: train/bike_s_001739.png to s3://ml-etl-project/train/bike_s_001739.png
# upload: train/bike_s_001761.png to s3://ml-etl-project/train/bike_s_001761.png
# upload: train/bike_s_001827.png to s3://ml-etl-project/train/bike_s_001827.png
# upload: train/bike_s_001414.png to s3://ml-etl-project/train/bike_s_001414.png
# upload: train/bike_s_001679.png to s3://ml-etl-project/train/bike_s_001679.png
# upload: train/bike_s_001683.png to s3://ml-etl-project/train/bike_s_001683.png
# upload: train/bike_s_001375.png to s3://ml-etl-project/train/bike_s_001375.png
# upload: train/bike_s_001847.png to s3://ml-etl-project/train/bike_s_001847.png
# upload: train/bike_s_001839.png to s3://ml-etl-project/train/bike_s_001839.png
# upload: train/bike_s_001767.png to s3://ml-etl-project/train/bike_s_001767.png
# upload: train/bike_s_001882.png to s3://ml-etl-project/train/bike_s_001882.png
# upload: train/bike_s_001877.png to s3://ml-etl-project/train/bike_s_001877.png
# upload: train/bike_s_001915.png to s3://ml-etl-project/train/bike_s_001915.png
# upload: train/bike_s_002024.png to s3://ml-etl-project/train/bike_s_002024.png
# upload: train/bike_s_001945.png to s3://ml-etl-project/train/bike_s_001945.png
# upload: train/bike_s_001897.png to s3://ml-etl-project/train/bike_s_001897.png
# upload: train/bike_s_002042.png to s3://ml-etl-project/train/bike_s_002042.png
# upload: train/bike_s_002098.png to s3://ml-etl-project/train/bike_s_002098.png
# upload: train/bike_s_002033.png to s3://ml-etl-project/train/bike_s_002033.png
# upload: train/bike_s_001928.png to s3://ml-etl-project/train/bike_s_001928.png
# upload: train/bike_s_002109.png to s3://ml-etl-project/train/bike_s_002109.png
# upload: train/bike_s_002047.png to s3://ml-etl-project/train/bike_s_002047.png
# upload: train/bike_s_002090.png to s3://ml-etl-project/train/bike_s_002090.png
# upload: train/bike_s_001980.png to s3://ml-etl-project/train/bike_s_001980.png
# upload: train/bike_s_001876.png to s3://ml-etl-project/train/bike_s_001876.png
# upload: train/bike_s_002139.png to s3://ml-etl-project/train/bike_s_002139.png
# upload: train/bike_s_002118.png to s3://ml-etl-project/train/bike_s_002118.png
# upload: train/bike_s_002164.png to s3://ml-etl-project/train/bike_s_002164.png
# upload: train/bike_s_002203.png to s3://ml-etl-project/train/bike_s_002203.png
# upload: train/bike_s_002283.png to s3://ml-etl-project/train/bike_s_002283.png
# upload: train/bike_s_002215.png to s3://ml-etl-project/train/bike_s_002215.png
# upload: train/bike_s_002292.png to s3://ml-etl-project/train/bike_s_002292.png
# upload: train/bike_s_002277.png to s3://ml-etl-project/train/bike_s_002277.png
# upload: train/bike_s_002288.png to s3://ml-etl-project/train/bike_s_002288.png
# upload: train/cycle_s_000222.png to s3://ml-etl-project/train/cycle_s_000222.png
# upload: train/cycle_s_000583.png to s3://ml-etl-project/train/cycle_s_000583.png
# upload: train/cycle_s_000463.png to s3://ml-etl-project/train/cycle_s_000463.png
# upload: train/cycle_s_000042.png to s3://ml-etl-project/train/cycle_s_000042.png
# upload: train/cycle_s_000318.png to s3://ml-etl-project/train/cycle_s_000318.png
# upload: train/cycle_s_000492.png to s3://ml-etl-project/train/cycle_s_000492.png
# upload: train/cycle_s_000639.png to s3://ml-etl-project/train/cycle_s_000639.png
# upload: train/cycle_s_001309.png to s3://ml-etl-project/train/cycle_s_001309.png
# upload: train/cycle_s_000718.png to s3://ml-etl-project/train/cycle_s_000718.png
# upload: train/cycle_s_001412.png to s3://ml-etl-project/train/cycle_s_001412.png
# upload: train/cycle_s_000871.png to s3://ml-etl-project/train/cycle_s_000871.png
# upload: train/cycle_s_001413.png to s3://ml-etl-project/train/cycle_s_001413.png
# upload: train/cycle_s_001286.png to s3://ml-etl-project/train/cycle_s_001286.png
# upload: train/cycle_s_001374.png to s3://ml-etl-project/train/cycle_s_001374.png
# upload: train/cycle_s_001472.png to s3://ml-etl-project/train/cycle_s_001472.png
# upload: train/cycle_s_000899.png to s3://ml-etl-project/train/cycle_s_000899.png
# upload: train/bike_s_002222.png to s3://ml-etl-project/train/bike_s_002222.png
# upload: train/cycle_s_001477.png to s3://ml-etl-project/train/cycle_s_001477.png
# upload: train/cycle_s_001735.png to s3://ml-etl-project/train/cycle_s_001735.png
# upload: train/cycle_s_000666.png to s3://ml-etl-project/train/cycle_s_000666.png
# upload: train/cycle_s_001640.png to s3://ml-etl-project/train/cycle_s_001640.png
# upload: train/cycle_s_001439.png to s3://ml-etl-project/train/cycle_s_001439.png
# upload: train/cycle_s_002015.png to s3://ml-etl-project/train/cycle_s_002015.png
# upload: train/cycle_s_001875.png to s3://ml-etl-project/train/cycle_s_001875.png
# upload: train/cycle_s_002053.png to s3://ml-etl-project/train/cycle_s_002053.png
# upload: train/cycle_s_001745.png to s3://ml-etl-project/train/cycle_s_001745.png
# upload: train/cycle_s_001474.png to s3://ml-etl-project/train/cycle_s_001474.png
# upload: train/cycle_s_002092.png to s3://ml-etl-project/train/cycle_s_002092.png
# upload: train/cycle_s_001976.png to s3://ml-etl-project/train/cycle_s_001976.png
# upload: train/cycle_s_002090.png to s3://ml-etl-project/train/cycle_s_002090.png
# upload: train/cycle_s_002503.png to s3://ml-etl-project/train/cycle_s_002503.png
# upload: train/cycle_s_002399.png to s3://ml-etl-project/train/cycle_s_002399.png
# upload: train/cycle_s_002093.png to s3://ml-etl-project/train/cycle_s_002093.png
# upload: train/cycle_s_002168.png to s3://ml-etl-project/train/cycle_s_002168.png
# upload: train/cycle_s_002178.png to s3://ml-etl-project/train/cycle_s_002178.png
# upload: train/cycle_s_002659.png to s3://ml-etl-project/train/cycle_s_002659.png
# upload: train/cycle_s_002651.png to s3://ml-etl-project/train/cycle_s_002651.png
# upload: train/cycle_s_002638.png to s3://ml-etl-project/train/cycle_s_002638.png
# upload: train/cycle_s_002598.png to s3://ml-etl-project/train/cycle_s_002598.png
# upload: train/cycle_s_002666.png to s3://ml-etl-project/train/cycle_s_002666.png
# upload: train/cycle_s_002779.png to s3://ml-etl-project/train/cycle_s_002779.png
# upload: train/cycle_s_002703.png to s3://ml-etl-project/train/cycle_s_002703.png
# upload: train/cycle_s_002746.png to s3://ml-etl-project/train/cycle_s_002746.png
# upload: train/cycle_s_002882.png to s3://ml-etl-project/train/cycle_s_002882.png
# upload: train/cycle_s_002844.png to s3://ml-etl-project/train/cycle_s_002844.png
# upload: train/cycle_s_003026.png to s3://ml-etl-project/train/cycle_s_003026.png
# upload: train/cycle_s_003006.png to s3://ml-etl-project/train/cycle_s_003006.png
# upload: train/cycle_s_003008.png to s3://ml-etl-project/train/cycle_s_003008.png
# upload: train/cycle_s_002978.png to s3://ml-etl-project/train/cycle_s_002978.png
# upload: train/cycle_s_002904.png to s3://ml-etl-project/train/cycle_s_002904.png
# upload: train/cycle_s_003043.png to s3://ml-etl-project/train/cycle_s_003043.png
# upload: train/cycle_s_003122.png to s3://ml-etl-project/train/cycle_s_003122.png
# upload: train/cycle_s_003147.png to s3://ml-etl-project/train/cycle_s_003147.png
# upload: train/cycle_s_003162.png to s3://ml-etl-project/train/cycle_s_003162.png
# upload: train/dirt_bike_s_000030.png to s3://ml-etl-project/train/dirt_bike_s_000030.png
# upload: train/dirt_bike_s_000059.png to s3://ml-etl-project/train/dirt_bike_s_000059.png
# upload: train/dirt_bike_s_000003.png to s3://ml-etl-project/train/dirt_bike_s_000003.png
# upload: train/dirt_bike_s_000005.png to s3://ml-etl-project/train/dirt_bike_s_000005.png
# upload: train/dirt_bike_s_000017.png to s3://ml-etl-project/train/dirt_bike_s_000017.png
# upload: train/cycle_s_003148.png to s3://ml-etl-project/train/cycle_s_003148.png
# upload: train/dirt_bike_s_000124.png to s3://ml-etl-project/train/dirt_bike_s_000124.png
# upload: train/dirt_bike_s_000119.png to s3://ml-etl-project/train/dirt_bike_s_000119.png
# upload: train/dirt_bike_s_000134.png to s3://ml-etl-project/train/dirt_bike_s_000134.png
# upload: train/minibike_s_000020.png to s3://ml-etl-project/train/minibike_s_000020.png
# upload: train/minibike_s_000010.png to s3://ml-etl-project/train/minibike_s_000010.png
# upload: train/minibike_s_000022.png to s3://ml-etl-project/train/minibike_s_000022.png
# upload: train/minibike_s_000064.png to s3://ml-etl-project/train/minibike_s_000064.png
# upload: train/minibike_s_000036.png to s3://ml-etl-project/train/minibike_s_000036.png
# upload: train/minibike_s_000035.png to s3://ml-etl-project/train/minibike_s_000035.png
# upload: train/minibike_s_000099.png to s3://ml-etl-project/train/minibike_s_000099.png
# upload: train/minibike_s_000011.png to s3://ml-etl-project/train/minibike_s_000011.png
# upload: train/minibike_s_000108.png to s3://ml-etl-project/train/minibike_s_000108.png
# upload: train/minibike_s_000121.png to s3://ml-etl-project/train/minibike_s_000121.png
# upload: train/minibike_s_000117.png to s3://ml-etl-project/train/minibike_s_000117.png
# upload: train/minibike_s_000110.png to s3://ml-etl-project/train/minibike_s_000110.png
# upload: train/minibike_s_000130.png to s3://ml-etl-project/train/minibike_s_000130.png
# upload: train/minibike_s_000127.png to s3://ml-etl-project/train/minibike_s_000127.png
# upload: train/minibike_s_000102.png to s3://ml-etl-project/train/minibike_s_000102.png
# upload: train/minibike_s_000116.png to s3://ml-etl-project/train/minibike_s_000116.png
# upload: train/minibike_s_000149.png to s3://ml-etl-project/train/minibike_s_000149.png
# upload: train/minibike_s_000146.png to s3://ml-etl-project/train/minibike_s_000146.png
# upload: train/minibike_s_000293.png to s3://ml-etl-project/train/minibike_s_000293.png
# upload: train/minibike_s_000165.png to s3://ml-etl-project/train/minibike_s_000165.png
# upload: train/minibike_s_000244.png to s3://ml-etl-project/train/minibike_s_000244.png
# upload: train/minibike_s_000314.png to s3://ml-etl-project/train/minibike_s_000314.png
# upload: train/minibike_s_000335.png to s3://ml-etl-project/train/minibike_s_000335.png
# upload: train/minibike_s_000203.png to s3://ml-etl-project/train/minibike_s_000203.png
# upload: train/minibike_s_000218.png to s3://ml-etl-project/train/minibike_s_000218.png
# upload: train/minibike_s_000324.png to s3://ml-etl-project/train/minibike_s_000324.png
# upload: train/minibike_s_000340.png to s3://ml-etl-project/train/minibike_s_000340.png
# upload: train/minibike_s_000402.png to s3://ml-etl-project/train/minibike_s_000402.png
# upload: train/minibike_s_000429.png to s3://ml-etl-project/train/minibike_s_000429.png
# upload: train/minibike_s_000434.png to s3://ml-etl-project/train/minibike_s_000434.png
# upload: train/minibike_s_000350.png to s3://ml-etl-project/train/minibike_s_000350.png
# upload: train/minibike_s_000392.png to s3://ml-etl-project/train/minibike_s_000392.png
# upload: train/minibike_s_000362.png to s3://ml-etl-project/train/minibike_s_000362.png
# upload: train/minibike_s_000408.png to s3://ml-etl-project/train/minibike_s_000408.png
# upload: train/minibike_s_000409.png to s3://ml-etl-project/train/minibike_s_000409.png
# upload: train/minibike_s_000435.png to s3://ml-etl-project/train/minibike_s_000435.png
# upload: train/minibike_s_000451.png to s3://ml-etl-project/train/minibike_s_000451.png
# upload: train/minibike_s_000485.png to s3://ml-etl-project/train/minibike_s_000485.png
# upload: train/minibike_s_000459.png to s3://ml-etl-project/train/minibike_s_000459.png
# upload: train/minibike_s_000507.png to s3://ml-etl-project/train/minibike_s_000507.png
# upload: train/minibike_s_000511.png to s3://ml-etl-project/train/minibike_s_000511.png
# upload: train/minibike_s_000527.png to s3://ml-etl-project/train/minibike_s_000527.png
# upload: train/minibike_s_000526.png to s3://ml-etl-project/train/minibike_s_000526.png
# upload: train/minibike_s_000491.png to s3://ml-etl-project/train/minibike_s_000491.png
# upload: train/minibike_s_000522.png to s3://ml-etl-project/train/minibike_s_000522.png
# upload: train/minibike_s_000498.png to s3://ml-etl-project/train/minibike_s_000498.png
# upload: train/minibike_s_000427.png to s3://ml-etl-project/train/minibike_s_000427.png
# upload: train/minibike_s_000520.png to s3://ml-etl-project/train/minibike_s_000520.png
# upload: train/minibike_s_000519.png to s3://ml-etl-project/train/minibike_s_000519.png
# upload: train/minibike_s_000518.png to s3://ml-etl-project/train/minibike_s_000518.png
# upload: train/minibike_s_000566.png to s3://ml-etl-project/train/minibike_s_000566.png
# upload: train/minibike_s_000571.png to s3://ml-etl-project/train/minibike_s_000571.png
# upload: train/minibike_s_000613.png to s3://ml-etl-project/train/minibike_s_000613.png
# upload: train/minibike_s_000567.png to s3://ml-etl-project/train/minibike_s_000567.png
# upload: train/minibike_s_000565.png to s3://ml-etl-project/train/minibike_s_000565.png
# upload: train/minibike_s_000652.png to s3://ml-etl-project/train/minibike_s_000652.png
# upload: train/minibike_s_000570.png to s3://ml-etl-project/train/minibike_s_000570.png
# upload: train/minibike_s_000569.png to s3://ml-etl-project/train/minibike_s_000569.png
# upload: train/minibike_s_000568.png to s3://ml-etl-project/train/minibike_s_000568.png
# upload: train/minibike_s_000690.png to s3://ml-etl-project/train/minibike_s_000690.png
# upload: train/minibike_s_000654.png to s3://ml-etl-project/train/minibike_s_000654.png
# upload: train/minibike_s_000698.png to s3://ml-etl-project/train/minibike_s_000698.png
# upload: train/minibike_s_000709.png to s3://ml-etl-project/train/minibike_s_000709.png
# upload: train/minibike_s_000738.png to s3://ml-etl-project/train/minibike_s_000738.png
# upload: train/minibike_s_000743.png to s3://ml-etl-project/train/minibike_s_000743.png
# upload: train/minibike_s_000800.png to s3://ml-etl-project/train/minibike_s_000800.png
# upload: train/minibike_s_000802.png to s3://ml-etl-project/train/minibike_s_000802.png
# upload: train/minibike_s_000741.png to s3://ml-etl-project/train/minibike_s_000741.png
# upload: train/minibike_s_000701.png to s3://ml-etl-project/train/minibike_s_000701.png
# upload: train/minibike_s_000813.png to s3://ml-etl-project/train/minibike_s_000813.png
# upload: train/minibike_s_000824.png to s3://ml-etl-project/train/minibike_s_000824.png
# upload: train/minibike_s_000820.png to s3://ml-etl-project/train/minibike_s_000820.png
# upload: train/minibike_s_000885.png to s3://ml-etl-project/train/minibike_s_000885.png
# upload: train/minibike_s_000855.png to s3://ml-etl-project/train/minibike_s_000855.png
# upload: train/minibike_s_000906.png to s3://ml-etl-project/train/minibike_s_000906.png
# upload: train/minibike_s_000831.png to s3://ml-etl-project/train/minibike_s_000831.png
# upload: train/minibike_s_000830.png to s3://ml-etl-project/train/minibike_s_000830.png
# upload: train/minibike_s_000967.png to s3://ml-etl-project/train/minibike_s_000967.png
# upload: train/minibike_s_001016.png to s3://ml-etl-project/train/minibike_s_001016.png
# upload: train/minibike_s_000886.png to s3://ml-etl-project/train/minibike_s_000886.png
# upload: train/minibike_s_000914.png to s3://ml-etl-project/train/minibike_s_000914.png
# upload: train/minibike_s_001079.png to s3://ml-etl-project/train/minibike_s_001079.png
# upload: train/minibike_s_000968.png to s3://ml-etl-project/train/minibike_s_000968.png
# upload: train/minibike_s_001072.png to s3://ml-etl-project/train/minibike_s_001072.png
# upload: train/minibike_s_001017.png to s3://ml-etl-project/train/minibike_s_001017.png
# upload: train/minibike_s_001169.png to s3://ml-etl-project/train/minibike_s_001169.png
# upload: train/minibike_s_001157.png to s3://ml-etl-project/train/minibike_s_001157.png
# upload: train/minibike_s_001094.png to s3://ml-etl-project/train/minibike_s_001094.png
# upload: train/minibike_s_000401.png to s3://ml-etl-project/train/minibike_s_000401.png
# upload: train/minibike_s_001185.png to s3://ml-etl-project/train/minibike_s_001185.png
# upload: train/minibike_s_001177.png to s3://ml-etl-project/train/minibike_s_001177.png
# upload: train/minibike_s_001250.png to s3://ml-etl-project/train/minibike_s_001250.png
# upload: train/minibike_s_001270.png to s3://ml-etl-project/train/minibike_s_001270.png
# upload: train/minibike_s_001191.png to s3://ml-etl-project/train/minibike_s_001191.png
# upload: train/minibike_s_001179.png to s3://ml-etl-project/train/minibike_s_001179.png
# upload: train/minibike_s_001168.png to s3://ml-etl-project/train/minibike_s_001168.png
# upload: train/minibike_s_001261.png to s3://ml-etl-project/train/minibike_s_001261.png
# upload: train/minibike_s_001193.png to s3://ml-etl-project/train/minibike_s_001193.png
# upload: train/minibike_s_001249.png to s3://ml-etl-project/train/minibike_s_001249.png
# upload: train/minibike_s_001344.png to s3://ml-etl-project/train/minibike_s_001344.png
# upload: train/minibike_s_001275.png to s3://ml-etl-project/train/minibike_s_001275.png
# upload: train/minibike_s_001345.png to s3://ml-etl-project/train/minibike_s_001345.png
# upload: train/minibike_s_001279.png to s3://ml-etl-project/train/minibike_s_001279.png
# upload: train/minibike_s_001294.png to s3://ml-etl-project/train/minibike_s_001294.png
# upload: train/minibike_s_001348.png to s3://ml-etl-project/train/minibike_s_001348.png
# upload: train/minibike_s_001366.png to s3://ml-etl-project/train/minibike_s_001366.png
# upload: train/minibike_s_001417.png to s3://ml-etl-project/train/minibike_s_001417.png
# upload: train/minibike_s_001450.png to s3://ml-etl-project/train/minibike_s_001450.png
# upload: train/minibike_s_001479.png to s3://ml-etl-project/train/minibike_s_001479.png
# upload: train/minibike_s_001512.png to s3://ml-etl-project/train/minibike_s_001512.png
# upload: train/minibike_s_001458.png to s3://ml-etl-project/train/minibike_s_001458.png
# upload: train/minibike_s_001511.png to s3://ml-etl-project/train/minibike_s_001511.png
# upload: train/minibike_s_001540.png to s3://ml-etl-project/train/minibike_s_001540.png
# upload: train/minibike_s_001498.png to s3://ml-etl-project/train/minibike_s_001498.png
# upload: train/minibike_s_001546.png to s3://ml-etl-project/train/minibike_s_001546.png
# upload: train/minibike_s_001491.png to s3://ml-etl-project/train/minibike_s_001491.png
# upload: train/minibike_s_001506.png to s3://ml-etl-project/train/minibike_s_001506.png
# upload: train/minibike_s_001496.png to s3://ml-etl-project/train/minibike_s_001496.png
# upload: train/minibike_s_001539.png to s3://ml-etl-project/train/minibike_s_001539.png
# upload: train/minibike_s_001558.png to s3://ml-etl-project/train/minibike_s_001558.png
# upload: train/minibike_s_001565.png to s3://ml-etl-project/train/minibike_s_001565.png
# upload: train/minibike_s_001573.png to s3://ml-etl-project/train/minibike_s_001573.png
# upload: train/minibike_s_001575.png to s3://ml-etl-project/train/minibike_s_001575.png
# upload: train/minibike_s_001653.png to s3://ml-etl-project/train/minibike_s_001653.png
# upload: train/minibike_s_001639.png to s3://ml-etl-project/train/minibike_s_001639.png
# upload: train/minibike_s_001638.png to s3://ml-etl-project/train/minibike_s_001638.png
# upload: train/minibike_s_001689.png to s3://ml-etl-project/train/minibike_s_001689.png
# upload: train/minibike_s_001691.png to s3://ml-etl-project/train/minibike_s_001691.png
# upload: train/minibike_s_001731.png to s3://ml-etl-project/train/minibike_s_001731.png
# upload: train/minibike_s_001701.png to s3://ml-etl-project/train/minibike_s_001701.png
# upload: train/minibike_s_001631.png to s3://ml-etl-project/train/minibike_s_001631.png
# upload: train/minibike_s_001734.png to s3://ml-etl-project/train/minibike_s_001734.png
# upload: train/minibike_s_001597.png to s3://ml-etl-project/train/minibike_s_001597.png
# upload: train/minibike_s_001827.png to s3://ml-etl-project/train/minibike_s_001827.png
# upload: train/minibike_s_001771.png to s3://ml-etl-project/train/minibike_s_001771.png
# upload: train/minibike_s_001836.png to s3://ml-etl-project/train/minibike_s_001836.png
# upload: train/minibike_s_001747.png to s3://ml-etl-project/train/minibike_s_001747.png
# upload: train/minibike_s_001829.png to s3://ml-etl-project/train/minibike_s_001829.png
# upload: train/minibike_s_001789.png to s3://ml-etl-project/train/minibike_s_001789.png
# upload: train/minibike_s_001767.png to s3://ml-etl-project/train/minibike_s_001767.png
# upload: train/minibike_s_001838.png to s3://ml-etl-project/train/minibike_s_001838.png
# upload: train/minibike_s_001921.png to s3://ml-etl-project/train/minibike_s_001921.png
# upload: train/minibike_s_001885.png to s3://ml-etl-project/train/minibike_s_001885.png
# upload: train/minibike_s_001880.png to s3://ml-etl-project/train/minibike_s_001880.png
# upload: train/minibike_s_001863.png to s3://ml-etl-project/train/minibike_s_001863.png
# upload: train/minibike_s_001881.png to s3://ml-etl-project/train/minibike_s_001881.png
# upload: train/minibike_s_001873.png to s3://ml-etl-project/train/minibike_s_001873.png
# upload: train/minibike_s_001870.png to s3://ml-etl-project/train/minibike_s_001870.png
# upload: train/minibike_s_002038.png to s3://ml-etl-project/train/minibike_s_002038.png
# upload: train/minibike_s_001996.png to s3://ml-etl-project/train/minibike_s_001996.png
# upload: train/minibike_s_001944.png to s3://ml-etl-project/train/minibike_s_001944.png
# upload: train/minibike_s_001865.png to s3://ml-etl-project/train/minibike_s_001865.png
# upload: train/minibike_s_001917.png to s3://ml-etl-project/train/minibike_s_001917.png
# upload: train/minibike_s_002030.png to s3://ml-etl-project/train/minibike_s_002030.png
# upload: train/minibike_s_001969.png to s3://ml-etl-project/train/minibike_s_001969.png
# upload: train/minibike_s_002009.png to s3://ml-etl-project/train/minibike_s_002009.png
# upload: train/minibike_s_002046.png to s3://ml-etl-project/train/minibike_s_002046.png
# upload: train/minibike_s_002146.png to s3://ml-etl-project/train/minibike_s_002146.png
# upload: train/minibike_s_002130.png to s3://ml-etl-project/train/minibike_s_002130.png
# upload: train/minibike_s_002137.png to s3://ml-etl-project/train/minibike_s_002137.png
# upload: train/minibike_s_002163.png to s3://ml-etl-project/train/minibike_s_002163.png
# upload: train/minibike_s_002048.png to s3://ml-etl-project/train/minibike_s_002048.png
# upload: train/minibike_s_002124.png to s3://ml-etl-project/train/minibike_s_002124.png
# upload: train/minibike_s_002084.png to s3://ml-etl-project/train/minibike_s_002084.png
# upload: train/minibike_s_001972.png to s3://ml-etl-project/train/minibike_s_001972.png
# upload: train/minibike_s_002176.png to s3://ml-etl-project/train/minibike_s_002176.png
# upload: train/minibike_s_002115.png to s3://ml-etl-project/train/minibike_s_002115.png
# upload: train/minibike_s_002182.png to s3://ml-etl-project/train/minibike_s_002182.png
# upload: train/minibike_s_002186.png to s3://ml-etl-project/train/minibike_s_002186.png
# upload: train/minibike_s_002196.png to s3://ml-etl-project/train/minibike_s_002196.png
# upload: train/minibike_s_002218.png to s3://ml-etl-project/train/minibike_s_002218.png
# upload: train/minibike_s_002194.png to s3://ml-etl-project/train/minibike_s_002194.png
# upload: train/moped_s_000004.png to s3://ml-etl-project/train/moped_s_000004.png
# upload: train/moped_s_000009.png to s3://ml-etl-project/train/moped_s_000009.png
# upload: train/minibike_s_002198.png to s3://ml-etl-project/train/minibike_s_002198.png
# upload: train/moped_s_000030.png to s3://ml-etl-project/train/moped_s_000030.png
# upload: train/moped_s_000034.png to s3://ml-etl-project/train/moped_s_000034.png
# upload: train/moped_s_000021.png to s3://ml-etl-project/train/moped_s_000021.png
# upload: train/moped_s_000035.png to s3://ml-etl-project/train/moped_s_000035.png
# upload: train/moped_s_000044.png to s3://ml-etl-project/train/moped_s_000044.png
# upload: train/moped_s_000065.png to s3://ml-etl-project/train/moped_s_000065.png
# upload: train/moped_s_000119.png to s3://ml-etl-project/train/moped_s_000119.png
# upload: train/moped_s_000071.png to s3://ml-etl-project/train/moped_s_000071.png
# upload: train/moped_s_000135.png to s3://ml-etl-project/train/moped_s_000135.png
# upload: train/moped_s_000236.png to s3://ml-etl-project/train/moped_s_000236.png
# upload: train/moped_s_000124.png to s3://ml-etl-project/train/moped_s_000124.png
# upload: train/moped_s_000168.png to s3://ml-etl-project/train/moped_s_000168.png
# upload: train/motorbike_s_000035.png to s3://ml-etl-project/train/motorbike_s_000035.png
# upload: train/motorbike_s_000009.png to s3://ml-etl-project/train/motorbike_s_000009.png
# upload: train/moped_s_000169.png to s3://ml-etl-project/train/moped_s_000169.png
# upload: train/motorbike_s_000021.png to s3://ml-etl-project/train/motorbike_s_000021.png
# upload: train/motorbike_s_000022.png to s3://ml-etl-project/train/motorbike_s_000022.png
# upload: train/motorbike_s_000062.png to s3://ml-etl-project/train/motorbike_s_000062.png
# upload: train/moped_s_000237.png to s3://ml-etl-project/train/moped_s_000237.png
# upload: train/motorbike_s_000106.png to s3://ml-etl-project/train/motorbike_s_000106.png
# upload: train/motorbike_s_000060.png to s3://ml-etl-project/train/motorbike_s_000060.png
# upload: train/motorbike_s_000068.png to s3://ml-etl-project/train/motorbike_s_000068.png
# upload: train/motorbike_s_000058.png to s3://ml-etl-project/train/motorbike_s_000058.png
# upload: train/motorbike_s_000117.png to s3://ml-etl-project/train/motorbike_s_000117.png
# upload: train/motorbike_s_000041.png to s3://ml-etl-project/train/motorbike_s_000041.png
# upload: train/motorbike_s_000119.png to s3://ml-etl-project/train/motorbike_s_000119.png
# upload: train/motorbike_s_000221.png to s3://ml-etl-project/train/motorbike_s_000221.png
# upload: train/motorbike_s_000134.png to s3://ml-etl-project/train/motorbike_s_000134.png
# upload: train/motorbike_s_000141.png to s3://ml-etl-project/train/motorbike_s_000141.png
# upload: train/motorbike_s_000172.png to s3://ml-etl-project/train/motorbike_s_000172.png
# upload: train/motorbike_s_000115.png to s3://ml-etl-project/train/motorbike_s_000115.png
# upload: train/motorbike_s_000124.png to s3://ml-etl-project/train/motorbike_s_000124.png
# upload: train/motorbike_s_000254.png to s3://ml-etl-project/train/motorbike_s_000254.png
# upload: train/motorbike_s_000308.png to s3://ml-etl-project/train/motorbike_s_000308.png
# upload: train/motorbike_s_000225.png to s3://ml-etl-project/train/motorbike_s_000225.png
# upload: train/motorbike_s_000223.png to s3://ml-etl-project/train/motorbike_s_000223.png
# upload: train/motorbike_s_000331.png to s3://ml-etl-project/train/motorbike_s_000331.png
# upload: train/motorbike_s_000463.png to s3://ml-etl-project/train/motorbike_s_000463.png
# upload: train/motorbike_s_000541.png to s3://ml-etl-project/train/motorbike_s_000541.png
# upload: train/motorbike_s_000427.png to s3://ml-etl-project/train/motorbike_s_000427.png
# upload: train/motorbike_s_000361.png to s3://ml-etl-project/train/motorbike_s_000361.png
# upload: train/motorbike_s_000449.png to s3://ml-etl-project/train/motorbike_s_000449.png
# upload: train/motorbike_s_000534.png to s3://ml-etl-project/train/motorbike_s_000534.png
# upload: train/motorbike_s_000501.png to s3://ml-etl-project/train/motorbike_s_000501.png
# upload: train/motorbike_s_000578.png to s3://ml-etl-project/train/motorbike_s_000578.png
# upload: train/motorbike_s_000362.png to s3://ml-etl-project/train/motorbike_s_000362.png
# upload: train/motorcycle_s_000004.png to s3://ml-etl-project/train/motorcycle_s_000004.png
# upload: train/motorcycle_s_000001.png to s3://ml-etl-project/train/motorcycle_s_000001.png
# upload: train/motorcycle_s_000022.png to s3://ml-etl-project/train/motorcycle_s_000022.png
# upload: train/motorbike_s_000346.png to s3://ml-etl-project/train/motorbike_s_000346.png
# upload: train/motorcycle_s_000026.png to s3://ml-etl-project/train/motorcycle_s_000026.png
# upload: train/motorcycle_s_000009.png to s3://ml-etl-project/train/motorcycle_s_000009.png
# upload: train/motorcycle_s_000002.png to s3://ml-etl-project/train/motorcycle_s_000002.png
# upload: train/motorcycle_s_000025.png to s3://ml-etl-project/train/motorcycle_s_000025.png
# upload: train/motorcycle_s_000029.png to s3://ml-etl-project/train/motorcycle_s_000029.png
# upload: train/motorcycle_s_000050.png to s3://ml-etl-project/train/motorcycle_s_000050.png
# upload: train/motorcycle_s_000003.png to s3://ml-etl-project/train/motorcycle_s_000003.png
# upload: train/motorcycle_s_000074.png to s3://ml-etl-project/train/motorcycle_s_000074.png
# upload: train/motorcycle_s_000070.png to s3://ml-etl-project/train/motorcycle_s_000070.png
# upload: train/motorcycle_s_000072.png to s3://ml-etl-project/train/motorcycle_s_000072.png
# upload: train/motorcycle_s_000032.png to s3://ml-etl-project/train/motorcycle_s_000032.png
# upload: train/motorcycle_s_000127.png to s3://ml-etl-project/train/motorcycle_s_000127.png
# upload: train/motorcycle_s_000126.png to s3://ml-etl-project/train/motorcycle_s_000126.png
# upload: train/motorcycle_s_000144.png to s3://ml-etl-project/train/motorcycle_s_000144.png
# upload: train/motorcycle_s_000027.png to s3://ml-etl-project/train/motorcycle_s_000027.png
# upload: train/motorcycle_s_000076.png to s3://ml-etl-project/train/motorcycle_s_000076.png
# upload: train/motorcycle_s_000154.png to s3://ml-etl-project/train/motorcycle_s_000154.png
# upload: train/motorcycle_s_000136.png to s3://ml-etl-project/train/motorcycle_s_000136.png
# upload: train/motorcycle_s_000169.png to s3://ml-etl-project/train/motorcycle_s_000169.png
# upload: train/motorcycle_s_000216.png to s3://ml-etl-project/train/motorcycle_s_000216.png
# upload: train/motorcycle_s_000133.png to s3://ml-etl-project/train/motorcycle_s_000133.png
# upload: train/motorcycle_s_000170.png to s3://ml-etl-project/train/motorcycle_s_000170.png
# ...
# upload: test/bike_s_000330.png to s3://ml-etl-project/test/bike_s_000330.png
# upload: test/bike_s_000457.png to s3://ml-etl-project/test/bike_s_000457.png
# upload: test/bike_s_001068.png to s3://ml-etl-project/test/bike_s_001068.png
# upload: test/bike_s_001073.png to s3://ml-etl-project/test/bike_s_001073.png
# upload: test/bike_s_000163.png to s3://ml-etl-project/test/bike_s_000163.png
# upload: test/bike_s_000487.png to s3://ml-etl-project/test/bike_s_000487.png
# upload: test/bike_s_001159.png to s3://ml-etl-project/test/bike_s_001159.png
# upload: test/bike_s_000694.png to s3://ml-etl-project/test/bike_s_000694.png
# upload: test/bike_s_000801.png to s3://ml-etl-project/test/bike_s_000801.png
# upload: test/bike_s_000941.png to s3://ml-etl-project/test/bike_s_000941.png
# upload: test/bike_s_001216.png to s3://ml-etl-project/test/bike_s_001216.png
# upload: test/bike_s_002009.png to s3://ml-etl-project/test/bike_s_002009.png
# upload: test/cycle_s_000010.png to s3://ml-etl-project/test/cycle_s_000010.png
# upload: test/bike_s_002208.png to s3://ml-etl-project/test/bike_s_002208.png
# upload: test/cycle_s_000970.png to s3://ml-etl-project/test/cycle_s_000970.png
# upload: test/bike_s_001852.png to s3://ml-etl-project/test/bike_s_001852.png
# upload: test/bike_s_002116.png to s3://ml-etl-project/test/bike_s_002116.png
# upload: test/cycle_s_000068.png to s3://ml-etl-project/test/cycle_s_000068.png
# upload: test/bike_s_001738.png to s3://ml-etl-project/test/bike_s_001738.png
# upload: test/bike_s_001342.png to s3://ml-etl-project/test/bike_s_001342.png
# upload: test/bike_s_001784.png to s3://ml-etl-project/test/bike_s_001784.png
# upload: test/cycle_s_001297.png to s3://ml-etl-project/test/cycle_s_001297.png
# upload: test/cycle_s_001648.png to s3://ml-etl-project/test/cycle_s_001648.png
# upload: test/cycle_s_001044.png to s3://ml-etl-project/test/cycle_s_001044.png
# upload: test/cycle_s_002305.png to s3://ml-etl-project/test/cycle_s_002305.png
# upload: test/cycle_s_001953.png to s3://ml-etl-project/test/cycle_s_001953.png
# upload: test/cycle_s_001214.png to s3://ml-etl-project/test/cycle_s_001214.png
# upload: test/cycle_s_001915.png to s3://ml-etl-project/test/cycle_s_001915.png
# upload: test/cycle_s_002661.png to s3://ml-etl-project/test/cycle_s_002661.png
# upload: test/cycle_s_002964.png to s3://ml-etl-project/test/cycle_s_002964.png
# upload: test/cycle_s_002613.png to s3://ml-etl-project/test/cycle_s_002613.png
# upload: test/cycle_s_001306.png to s3://ml-etl-project/test/cycle_s_001306.png
# upload: test/minibike_s_000075.png to s3://ml-etl-project/test/minibike_s_000075.png
# upload: test/dirt_bike_s_000001.png to s3://ml-etl-project/test/dirt_bike_s_000001.png
# upload: test/minibike_s_000288.png to s3://ml-etl-project/test/minibike_s_000288.png
# upload: test/minibike_s_000254.png to s3://ml-etl-project/test/minibike_s_000254.png
# upload: test/minibike_s_000309.png to s3://ml-etl-project/test/minibike_s_000309.png
# upload: test/minibike_s_000052.png to s3://ml-etl-project/test/minibike_s_000052.png
# upload: test/minibike_s_000398.png to s3://ml-etl-project/test/minibike_s_000398.png
# upload: test/minibike_s_000290.png to s3://ml-etl-project/test/minibike_s_000290.png
# upload: test/minibike_s_000497.png to s3://ml-etl-project/test/minibike_s_000497.png
# upload: test/minibike_s_000055.png to s3://ml-etl-project/test/minibike_s_000055.png
# upload: test/minibike_s_000573.png to s3://ml-etl-project/test/minibike_s_000573.png
# upload: test/minibike_s_000505.png to s3://ml-etl-project/test/minibike_s_000505.png
# upload: test/minibike_s_000801.png to s3://ml-etl-project/test/minibike_s_000801.png
# upload: test/minibike_s_000960.png to s3://ml-etl-project/test/minibike_s_000960.png
# upload: test/minibike_s_000828.png to s3://ml-etl-project/test/minibike_s_000828.png
# upload: test/minibike_s_000947.png to s3://ml-etl-project/test/minibike_s_000947.png
# upload: test/minibike_s_001441.png to s3://ml-etl-project/test/minibike_s_001441.png
# upload: test/minibike_s_000792.png to s3://ml-etl-project/test/minibike_s_000792.png
# upload: test/minibike_s_001089.png to s3://ml-etl-project/test/minibike_s_001089.png
# upload: test/minibike_s_001473.png to s3://ml-etl-project/test/minibike_s_001473.png
# upload: test/minibike_s_000880.png to s3://ml-etl-project/test/minibike_s_000880.png
# upload: test/minibike_s_000913.png to s3://ml-etl-project/test/minibike_s_000913.png
# upload: test/minibike_s_001605.png to s3://ml-etl-project/test/minibike_s_001605.png
# upload: test/minibike_s_001651.png to s3://ml-etl-project/test/minibike_s_001651.png
# upload: test/minibike_s_001893.png to s3://ml-etl-project/test/minibike_s_001893.png
# upload: test/moped_s_000007.png to s3://ml-etl-project/test/moped_s_000007.png
# upload: test/minibike_s_001732.png to s3://ml-etl-project/test/minibike_s_001732.png
# upload: test/minibike_s_002173.png to s3://ml-etl-project/test/minibike_s_002173.png
# upload: test/minibike_s_001547.png to s3://ml-etl-project/test/minibike_s_001547.png
# upload: test/minibike_s_001867.png to s3://ml-etl-project/test/minibike_s_001867.png
# upload: test/minibike_s_002227.png to s3://ml-etl-project/test/minibike_s_002227.png
# upload: test/minibike_s_002230.png to s3://ml-etl-project/test/minibike_s_002230.png
# upload: test/minibike_s_002051.png to s3://ml-etl-project/test/minibike_s_002051.png
# upload: test/moped_s_000033.png to s3://ml-etl-project/test/moped_s_000033.png
# upload: test/motorbike_s_000005.png to s3://ml-etl-project/test/motorbike_s_000005.png
# upload: test/motorbike_s_000433.png to s3://ml-etl-project/test/motorbike_s_000433.png
# upload: test/motorbike_s_000126.png to s3://ml-etl-project/test/motorbike_s_000126.png
# upload: test/moped_s_000064.png to s3://ml-etl-project/test/moped_s_000064.png
# upload: test/moped_s_000306.png to s3://ml-etl-project/test/moped_s_000306.png
# upload: test/motorbike_s_000324.png to s3://ml-etl-project/test/motorbike_s_000324.png
# upload: test/motorbike_s_000333.png to s3://ml-etl-project/test/motorbike_s_000333.png
# upload: test/motorbike_s_000121.png to s3://ml-etl-project/test/motorbike_s_000121.png
# upload: test/motorbike_s_000135.png to s3://ml-etl-project/test/motorbike_s_000135.png
# upload: test/motorcycle_s_000007.png to s3://ml-etl-project/test/motorcycle_s_000007.png
# upload: test/motorbike_s_000465.png to s3://ml-etl-project/test/motorbike_s_000465.png
# upload: test/motorcycle_s_000040.png to s3://ml-etl-project/test/motorcycle_s_000040.png
# upload: test/motorcycle_s_000139.png to s3://ml-etl-project/test/motorcycle_s_000139.png
# upload: test/motorcycle_s_000049.png to s3://ml-etl-project/test/motorcycle_s_000049.png
# upload: test/motorcycle_s_000141.png to s3://ml-etl-project/test/motorcycle_s_000141.png
# upload: test/motorbike_s_000629.png to s3://ml-etl-project/test/motorbike_s_000629.png
# upload: test/motorcycle_s_000171.png to s3://ml-etl-project/test/motorcycle_s_000171.png
# upload: test/motorcycle_s_000063.png to s3://ml-etl-project/test/motorcycle_s_000063.png
# upload: test/motorcycle_s_000211.png to s3://ml-etl-project/test/motorcycle_s_000211.png
# upload: test/motorcycle_s_000060.png to s3://ml-etl-project/test/motorcycle_s_000060.png
# upload: test/motorcycle_s_000446.png to s3://ml-etl-project/test/motorcycle_s_000446.png
# upload: test/motorcycle_s_000450.png to s3://ml-etl-project/test/motorcycle_s_000450.png
# upload: test/motorcycle_s_000042.png to s3://ml-etl-project/test/motorcycle_s_000042.png
# upload: test/motorcycle_s_000323.png to s3://ml-etl-project/test/motorcycle_s_000323.png
# upload: test/motorcycle_s_000352.png to s3://ml-etl-project/test/motorcycle_s_000352.png
# upload: test/motorcycle_s_000494.png to s3://ml-etl-project/test/motorcycle_s_000494.png
# upload: test/motorcycle_s_000222.png to s3://ml-etl-project/test/motorcycle_s_000222.png
# upload: test/motorcycle_s_000512.png to s3://ml-etl-project/test/motorcycle_s_000512.png
# upload: test/motorcycle_s_000602.png to s3://ml-etl-project/test/motorcycle_s_000602.png
# upload: test/motorcycle_s_000427.png to s3://ml-etl-project/test/motorcycle_s_000427.png
# upload: test/motorcycle_s_000606.png to s3://ml-etl-project/test/motorcycle_s_000606.png
# upload: test/motorcycle_s_000530.png to s3://ml-etl-project/test/motorcycle_s_000530.png
# upload: test/motorcycle_s_000679.png to s3://ml-etl-project/test/motorcycle_s_000679.png
# upload: test/motorcycle_s_000739.png to s3://ml-etl-project/test/motorcycle_s_000739.png
# upload: test/motorcycle_s_000485.png to s3://ml-etl-project/test/motorcycle_s_000485.png
# upload: test/motorcycle_s_000615.png to s3://ml-etl-project/test/motorcycle_s_000615.png
# upload: test/motorcycle_s_000825.png to s3://ml-etl-project/test/motorcycle_s_000825.png
# upload: test/motorcycle_s_000866.png to s3://ml-etl-project/test/motorcycle_s_000866.png
# upload: test/motorcycle_s_000797.png to s3://ml-etl-project/test/motorcycle_s_000797.png
# upload: test/motorcycle_s_001164.png to s3://ml-etl-project/test/motorcycle_s_001164.png
# upload: test/motorcycle_s_001249.png to s3://ml-etl-project/test/motorcycle_s_001249.png
# upload: test/motorcycle_s_000876.png to s3://ml-etl-project/test/motorcycle_s_000876.png
# upload: test/motorcycle_s_000878.png to s3://ml-etl-project/test/motorcycle_s_000878.png
# upload: test/motorcycle_s_000685.png to s3://ml-etl-project/test/motorcycle_s_000685.png
# upload: test/motorcycle_s_000963.png to s3://ml-etl-project/test/motorcycle_s_000963.png
# upload: test/motorcycle_s_001261.png to s3://ml-etl-project/test/motorcycle_s_001261.png
# upload: test/motorcycle_s_001348.png to s3://ml-etl-project/test/motorcycle_s_001348.png
# upload: test/motorcycle_s_001679.png to s3://ml-etl-project/test/motorcycle_s_001679.png
# upload: test/motorcycle_s_001687.png to s3://ml-etl-project/test/motorcycle_s_001687.png
# upload: test/motorcycle_s_001269.png to s3://ml-etl-project/test/motorcycle_s_001269.png
# upload: test/motorcycle_s_001906.png to s3://ml-etl-project/test/motorcycle_s_001906.png
# upload: test/motorcycle_s_001385.png to s3://ml-etl-project/test/motorcycle_s_001385.png
# upload: test/motorcycle_s_001892.png to s3://ml-etl-project/test/motorcycle_s_001892.png
# upload: test/motorcycle_s_001519.png to s3://ml-etl-project/test/motorcycle_s_001519.png
# upload: test/motorcycle_s_001782.png to s3://ml-etl-project/test/motorcycle_s_001782.png
# upload: test/motorcycle_s_001508.png to s3://ml-etl-project/test/motorcycle_s_001508.png
# upload: test/motorcycle_s_002112.png to s3://ml-etl-project/test/motorcycle_s_002112.png
# upload: test/motorcycle_s_002026.png to s3://ml-etl-project/test/motorcycle_s_002026.png
# upload: test/motorcycle_s_001955.png to s3://ml-etl-project/test/motorcycle_s_001955.png
# upload: test/ordinary_bicycle_s_000105.png to s3://ml-etl-project/test/ordinary_bicycle_s_000105.png
# upload: test/motorcycle_s_002177.png to s3://ml-etl-project/test/motorcycle_s_002177.png
# upload: test/ordinary_bicycle_s_000113.png to s3://ml-etl-project/test/ordinary_bicycle_s_000113.png
# upload: test/motorcycle_s_002126.png to s3://ml-etl-project/test/motorcycle_s_002126.png
# upload: test/motorcycle_s_001936.png to s3://ml-etl-project/test/motorcycle_s_001936.png
# upload: test/ordinary_bicycle_s_000169.png to s3://ml-etl-project/test/ordinary_bicycle_s_000169.png
# upload: test/motorcycle_s_001960.png to s3://ml-etl-project/test/motorcycle_s_001960.png
# upload: test/ordinary_bicycle_s_000284.png to s3://ml-etl-project/test/ordinary_bicycle_s_000284.png
# upload: test/ordinary_bicycle_s_000158.png to s3://ml-etl-project/test/ordinary_bicycle_s_000158.png
# upload: test/safety_bicycle_s_000315.png to s3://ml-etl-project/test/safety_bicycle_s_000315.png
# upload: test/safety_bicycle_s_000280.png to s3://ml-etl-project/test/safety_bicycle_s_000280.png
# upload: test/ordinary_bicycle_s_000431.png to s3://ml-etl-project/test/ordinary_bicycle_s_000431.png
# upload: test/motorcycle_s_001971.png to s3://ml-etl-project/test/motorcycle_s_001971.png
# upload: test/safety_bicycle_s_001322.png to s3://ml-etl-project/test/safety_bicycle_s_001322.png
# upload: test/safety_bicycle_s_001153.png to s3://ml-etl-project/test/safety_bicycle_s_001153.png
# upload: test/safety_bicycle_s_000235.png to s3://ml-etl-project/test/safety_bicycle_s_000235.png
# upload: test/safety_bicycle_s_001286.png to s3://ml-etl-project/test/safety_bicycle_s_001286.png
# upload: test/ordinary_bicycle_s_000350.png to s3://ml-etl-project/test/ordinary_bicycle_s_000350.png
# upload: test/safety_bike_s_000438.png to s3://ml-etl-project/test/safety_bike_s_000438.png
# upload: test/ordinary_bicycle_s_000437.png to s3://ml-etl-project/test/ordinary_bicycle_s_000437.png
# upload: test/safety_bike_s_000192.png to s3://ml-etl-project/test/safety_bike_s_000192.png
# upload: test/safety_bike_s_000699.png to s3://ml-etl-project/test/safety_bike_s_000699.png
# upload: test/safety_bike_s_000791.png to s3://ml-etl-project/test/safety_bike_s_000791.png
# upload: test/safety_bike_s_001065.png to s3://ml-etl-project/test/safety_bike_s_001065.png
# upload: test/safety_bike_s_000540.png to s3://ml-etl-project/test/safety_bike_s_000540.png
# upload: test/safety_bicycle_s_001575.png to s3://ml-etl-project/test/safety_bicycle_s_001575.png
# upload: test/safety_bike_s_000390.png to s3://ml-etl-project/test/safety_bike_s_000390.png
# upload: test/safety_bike_s_000488.png to s3://ml-etl-project/test/safety_bike_s_000488.png
# upload: test/safety_bike_s_001088.png to s3://ml-etl-project/test/safety_bike_s_001088.png
# upload: test/safety_bike_s_001132.png to s3://ml-etl-project/test/safety_bike_s_001132.png
# upload: test/trail_bike_s_000073.png to s3://ml-etl-project/test/trail_bike_s_000073.png
# upload: test/safety_bike_s_001253.png to s3://ml-etl-project/test/safety_bike_s_001253.png
# upload: test/safety_bike_s_001481.png to s3://ml-etl-project/test/safety_bike_s_001481.png
# upload: test/safety_bike_s_001087.png to s3://ml-etl-project/test/safety_bike_s_001087.png
# upload: test/safety_bike_s_000541.png to s3://ml-etl-project/test/safety_bike_s_000541.png
# upload: test/velocipede_s_000001.png to s3://ml-etl-project/test/velocipede_s_000001.png
# upload: test/safety_bike_s_001690.png to s3://ml-etl-project/test/safety_bike_s_001690.png
# upload: test/velocipede_s_000041.png to s3://ml-etl-project/test/velocipede_s_000041.png
# upload: test/velocipede_s_000106.png to s3://ml-etl-project/test/velocipede_s_000106.png
# upload: test/velocipede_s_000292.png to s3://ml-etl-project/test/velocipede_s_000292.png
# upload: test/velocipede_s_000369.png to s3://ml-etl-project/test/velocipede_s_000369.png
# upload: test/velocipede_s_001277.png to s3://ml-etl-project/test/velocipede_s_001277.png
# upload: test/velocipede_s_001335.png to s3://ml-etl-project/test/velocipede_s_001335.png
# upload: test/velocipede_s_001232.png to s3://ml-etl-project/test/velocipede_s_001232.png
# upload: test/velocipede_s_000863.png to s3://ml-etl-project/test/velocipede_s_000863.png
# upload: test/velocipede_s_001201.png to s3://ml-etl-project/test/velocipede_s_001201.png
# upload: test/velocipede_s_001355.png to s3://ml-etl-project/test/velocipede_s_001355.png
# upload: test/velocipede_s_001379.png to s3://ml-etl-project/test/velocipede_s_001379.png
# upload: test/velocipede_s_001633.png to s3://ml-etl-project/test/velocipede_s_001633.png
# upload: test/velocipede_s_001744.png to s3://ml-etl-project/test/velocipede_s_001744.png
# upload: test/velocipede_s_001466.png to s3://ml-etl-project/test/velocipede_s_001466.png
# upload: test/velocipede_s_001699.png to s3://ml-etl-project/test/velocipede_s_001699.png
# upload: test/velocipede_s_001790.png to s3://ml-etl-project/test/velocipede_s_001790.png

# %% [markdown]
# And that's it! You can check the bucket and verify that the items were uploaded.
#
# ## Model Training
#
# For Image Classification, Sagemaker [also expects metadata](https://docs.aws.amazon.com/sagemaker/latest/dg/image-classification.html) e.g. in the form of TSV files with labels and filepaths. We can generate these using our Pandas DataFrames from earlier:

# %%
def to_metadata_file(df, prefix):
    df["s3_path"] = df["filenames"]
    df["labels"] = df["labels"].apply(lambda x: 0 if x==8 else 1)
    return df[["row", "labels", "s3_path"]].to_csv(
        f"{prefix}.lst", sep="\t", index=False, header=False
    )
    
to_metadata_file(df_train.copy(), "train")
to_metadata_file(df_test.copy(), "test")

# %% [markdown]
# We can also upload our manifest files:

# %%
import boto3

# Upload files
boto3.Session().resource('s3').Bucket(
    bucket).Object('train.lst').upload_file('./train.lst')
boto3.Session().resource('s3').Bucket(
    bucket).Object('test.lst').upload_file('./test.lst')
# Out:
# [02/13/25 20:56:58] INFO     Found credentials from IAM Role:                                   ]8;id=362762;file:///home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages/botocore/credentials.py\credentials.py]8;;\:]8;id=373854;file:///home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages/botocore/credentials.py#1075\1075]8;;\
#                              BaseNotebookInstanceEc2InstanceRole
#                     INFO     Found credentials from IAM Role:                                   ]8;id=905738;file:///home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages/botocore/credentials.py\credentials.py]8;;\:]8;id=941750;file:///home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages/botocore/credentials.py#1075\1075]8;;\
#                              BaseNotebookInstanceEc2InstanceRole

# %% [markdown]
# Using the `bucket` and `region` info we can get the latest prebuilt container to run our training job, and define an output location on our s3 bucket for the model. Use the `image_uris` function from the SageMaker SDK to retrieve the latest `image-classification` image below:

# %%
# Use the image_uris function to retrieve the latest 'image-classification' image 
region = sagemaker.Session().boto_region_name
image_uri = sagemaker.image_uris.retrieve(
    framework='image-classification', region=region, version='latest')
s3_output_location = f"s3://{bucket}/models/image_model"
# Out:
# [02/13/25 20:57:04] INFO     Found credentials from IAM Role:                                   ]8;id=554816;file:///home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages/botocore/credentials.py\credentials.py]8;;\:]8;id=503327;file:///home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages/botocore/credentials.py#1075\1075]8;;\
#                              BaseNotebookInstanceEc2InstanceRole
#                     INFO     Same images used for training and inference. Defaulting to image     ]8;id=896609;file:///home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages/sagemaker/image_uris.py\image_uris.py]8;;\:]8;id=754157;file:///home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages/sagemaker/image_uris.py#391\391]8;;\
#                              scope: inference.
#                     INFO     Ignoring unnecessary instance type: None.                            ]8;id=783622;file:///home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages/sagemaker/image_uris.py\image_uris.py]8;;\:]8;id=543846;file:///home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages/sagemaker/image_uris.py#528\528]8;;\

# %% [markdown]
# We're ready to create an estimator! Create an estimator `img_classifier_model` that uses one instance of `ml.p3.2xlarge`. Ensure that y ou use the output location we defined above - we'll be referring to that later!

# %%
img_classifier_model = sagemaker.estimator.Estimator(
    # TODO: define your estimator options
    image_uri=image_uri,
    role=role,
    instance_count=1,
    instance_type='ml.p3.2xlarge',
    output_path=s3_output_location,
    vpc_config={
        'Subnets': [],
        'SecurityGroupIds': []
    },
    training_image_config={
        'RepositoryAccessMode': 'VPC'
    }
)
# Out:
# [02/13/25 20:58:24] INFO     Found credentials from IAM Role:                                   ]8;id=825524;file:///home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages/botocore/credentials.py\credentials.py]8;;\:]8;id=846727;file:///home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages/botocore/credentials.py#1075\1075]8;;\
#                              BaseNotebookInstanceEc2InstanceRole
# [02/13/25 20:58:25] INFO     Found credentials from IAM Role:                                   ]8;id=143967;file:///home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages/botocore/credentials.py\credentials.py]8;;\:]8;id=999289;file:///home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages/botocore/credentials.py#1075\1075]8;;\
#                              BaseNotebookInstanceEc2InstanceRole

# %% [markdown]
# We can also set a few key hyperparameters and define the inputs for our model:

# %%
img_classifier_model.set_hyperparameters(
    image_shape='3,32,32',
    num_classes=2,
    num_training_samples=1000
)

# %% [markdown]
# The `image-classification` image uses four input channels with very specific input parameters. For convenience, we've provided them below:

# %%
from sagemaker.debugger import Rule, rule_configs
from sagemaker.session import TrainingInput
model_inputs = {
        "train": sagemaker.inputs.TrainingInput(
            s3_data=f"s3://{bucket}/train/",
            content_type="application/x-image"
        ),
        "validation": sagemaker.inputs.TrainingInput(
            s3_data=f"s3://{bucket}/test/",
            content_type="application/x-image"
        ),
        "train_lst": sagemaker.inputs.TrainingInput(
            s3_data=f"s3://{bucket}/train.lst",
            content_type="application/x-image"
        ),
        "validation_lst": sagemaker.inputs.TrainingInput(
            s3_data=f"s3://{bucket}/test.lst",
            content_type="application/x-image"
        )
}

# %% [markdown]
# Great, now we can train the model using the model_inputs. In the cell below, call the `fit` method on our model,:

# %%
## TODO: train your model
img_classifier_model.fit(model_inputs, wait=True)
# Out:
# [02/13/25 21:02:00] INFO     SageMaker Python SDK will collect telemetry to help us better  ]8;id=393623;file:///home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages/sagemaker/telemetry/telemetry_logging.py\telemetry_logging.py]8;;\:]8;id=255996;file:///home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages/sagemaker/telemetry/telemetry_logging.py#90\90]8;;\
#                              understand our user's needs, diagnose issues, and deliver
#                              additional features.
#                              To opt out of telemetry, please disable via TelemetryOptOut
#                              parameter in SDK defaults config. For more information, refer
#                              to
#                              https://sagemaker.readthedocs.io/en/stable/overview.html#confi
#                              guring-and-using-defaults-with-the-sagemaker-python-sdk.
# [02/13/25 21:02:01] INFO     Creating training-job with name:                                       ]8;id=171401;file:///home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages/sagemaker/session.py\session.py]8;;\:]8;id=245139;file:///home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages/sagemaker/session.py#1042\1042]8;;\
#                              image-classification-2025-02-13-21-02-00-762
# 2025-02-13 21:02:02 Starting - Starting the training job
# .....02-13 21:02:02 Pending - Training job waiting for capacity.
# .....02-13 21:03:05 Pending - Preparing the instances for training.
# .......................nloading - Downloading the training image.
# ..Docker entrypoint called with argument(s): trainleted. Training in progress..
# Running default environment configuration script
# Nvidia gpu devices, drivers and cuda toolkit versions (only available on hosts with GPU):
# Thu Feb 13 21:08:31 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.144.03             Driver Version: 550.144.03     CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla V100-SXM2-16GB           On  |   00000000:00:1E.0 Off |                    0 |
# | N/A   29C    P0             22W /  300W |       1MiB /  16384MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+
# Checking for nvidia driver and cuda compatibility.
# CUDA Compatibility driver provided.
# Proceeding with compatibility check between driver, cuda-toolkit and cuda-compat.
# Detected cuda-toolkit version: 11.1.
# Detected cuda-compat version: 455.32.00.
# Detected Nvidia driver version: 550.144.03.
# Nvidia driver compatible with cuda-toolkit. Disabling cuda-compat.
# /opt/amazon/lib/python3.8/site-packages/mxnet/model.py:97: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if num_device is 1 and 'dist' not in kvstore:
# [02/13/2025 21:08:34 INFO 140278783489856] Reading default configuration from /opt/amazon/lib/python3.8/site-packages/image_classification/default-input.json: {'use_pretrained_model': 0, 'num_layers': 152, 'epochs': 30, 'learning_rate': 0.1, 'lr_scheduler_factor': 0.1, 'optimizer': 'sgd', 'momentum': 0, 'weight_decay': 0.0001, 'beta_1': 0.9, 'beta_2': 0.999, 'eps': 1e-08, 'gamma': 0.9, 'mini_batch_size': 32, 'image_shape': '3,224,224', 'precision_dtype': 'float32'}
# [02/13/2025 21:08:34 INFO 140278783489856] Merging with provided configuration from /opt/ml/input/config/hyperparameters.json: {'image_shape': '3,32,32', 'num_classes': '2', 'num_training_samples': '1000'}
# [02/13/2025 21:08:34 INFO 140278783489856] Final configuration: {'use_pretrained_model': 0, 'num_layers': 152, 'epochs': 30, 'learning_rate': 0.1, 'lr_scheduler_factor': 0.1, 'optimizer': 'sgd', 'momentum': 0, 'weight_decay': 0.0001, 'beta_1': 0.9, 'beta_2': 0.999, 'eps': 1e-08, 'gamma': 0.9, 'mini_batch_size': 32, 'image_shape': '3,32,32', 'precision_dtype': 'float32', 'num_classes': '2', 'num_training_samples': '1000'}
# [02/13/2025 21:08:34 INFO 140278783489856] Searching for .lst files in /opt/ml/input/data/train_lst.
# [02/13/2025 21:08:34 INFO 140278783489856] Creating record files for train.lst
# [02/13/2025 21:08:34 INFO 140278783489856] Done creating record files...
# [02/13/2025 21:08:34 INFO 140278783489856] Searching for .lst files in /opt/ml/input/data/validation_lst.
# [02/13/2025 21:08:34 INFO 140278783489856] Creating record files for test.lst
# [02/13/2025 21:08:34 INFO 140278783489856] Done creating record files...
# [02/13/2025 21:08:34 INFO 140278783489856] use_pretrained_model: 0
# [02/13/2025 21:08:34 INFO 140278783489856] multi_label: 0
# [02/13/2025 21:08:34 INFO 140278783489856] Performing random weight initialization
# [02/13/2025 21:08:34 INFO 140278783489856] ---- Parameters ----
# [02/13/2025 21:08:34 INFO 140278783489856] num_layers: 152
# [02/13/2025 21:08:34 INFO 140278783489856] data type: <class 'numpy.float32'>
# [02/13/2025 21:08:34 INFO 140278783489856] epochs: 30
# [02/13/2025 21:08:34 INFO 140278783489856] optimizer: sgd
# [02/13/2025 21:08:34 INFO 140278783489856] momentum: 0.9
# [02/13/2025 21:08:34 INFO 140278783489856] weight_decay: 0.0001
# [02/13/2025 21:08:34 INFO 140278783489856] learning_rate: 0.1
# [02/13/2025 21:08:34 INFO 140278783489856] num_training_samples: 1000
# [02/13/2025 21:08:34 INFO 140278783489856] mini_batch_size: 32
# [02/13/2025 21:08:34 INFO 140278783489856] image_shape: 3,32,32
# [02/13/2025 21:08:34 INFO 140278783489856] num_classes: 2
# [02/13/2025 21:08:34 INFO 140278783489856] augmentation_type: None
# [02/13/2025 21:08:34 INFO 140278783489856] kv_store: device
# [02/13/2025 21:08:34 INFO 140278783489856] checkpoint_frequency not set, will store the best model
# [02/13/2025 21:08:34 INFO 140278783489856] --------------------
# /opt/amazon/python3.8/lib/python3.8/subprocess.py:848: RuntimeWarning: line buffering (buffering=1) isn't supported in binary mode, the default buffer size will be used
#   self.stdout = io.open(c2pread, 'rb', bufsize)
# [02/13/2025 21:08:35 INFO 140278783489856] Setting number of threads: 7
# [21:08:39] /opt/brazil-pkg-cache/packages/AIAlgorithmsMXNet/AIAlgorithmsMXNet-1.4.x_ecl_Cuda_11.1.x.441.0/AL2_x86_64/generic-flavor/src/src/operator/nn/./cudnn/./cudnn_algoreg-inl.h:97: Running performance tests to find the best convolution algorithm, this can take a while... (setting env variable MXNET_CUDNN_AUTOTUNE_DEFAULT to 0 to disable)
# [02/13/2025 21:08:44 INFO 140278783489856] Epoch[0] Batch [20]#011Speed: 123.833 samples/sec#011accuracy=0.595238
# [02/13/2025 21:08:45 INFO 140278783489856] Epoch[0] Train-accuracy=0.644153
# [02/13/2025 21:08:45 INFO 140278783489856] Epoch[0] Time cost=6.779
# [02/13/2025 21:08:46 INFO 140278783489856] Epoch[0] Validation-accuracy=0.505208
# [02/13/2025 21:08:46 INFO 140278783489856] Storing the best model with validation accuracy: 0.505208
# [02/13/2025 21:08:47 INFO 140278783489856] Saved checkpoint to "/opt/ml/model/image-classification-0001.params"
# [02/13/2025 21:08:50 INFO 140278783489856] Epoch[1] Batch [20]#011Speed: 187.658 samples/sec#011accuracy=0.696429
# [02/13/2025 21:08:52 INFO 140278783489856] Epoch[1] Train-accuracy=0.713710
# [02/13/2025 21:08:52 INFO 140278783489856] Epoch[1] Time cost=5.046
# [02/13/2025 21:08:52 INFO 140278783489856] Epoch[1] Validation-accuracy=0.593750
# [02/13/2025 21:08:52 INFO 140278783489856] Storing the best model with validation accuracy: 0.593750
# [02/13/2025 21:08:53 INFO 140278783489856] Saved checkpoint to "/opt/ml/model/image-classification-0002.params"
# [02/13/2025 21:08:56 INFO 140278783489856] Epoch[2] Batch [20]#011Speed: 193.699 samples/sec#011accuracy=0.735119
# [02/13/2025 21:08:58 INFO 140278783489856] Epoch[2] Train-accuracy=0.709677
# [02/13/2025 21:08:58 INFO 140278783489856] Epoch[2] Time cost=4.921
# [02/13/2025 21:08:58 INFO 140278783489856] Epoch[2] Validation-accuracy=0.828125
# [02/13/2025 21:08:58 INFO 140278783489856] Storing the best model with validation accuracy: 0.828125
# [02/13/2025 21:08:59 INFO 140278783489856] Saved checkpoint to "/opt/ml/model/image-classification-0003.params"
# [02/13/2025 21:09:02 INFO 140278783489856] Epoch[3] Batch [20]#011Speed: 193.186 samples/sec#011accuracy=0.705357
# [02/13/2025 21:09:04 INFO 140278783489856] Epoch[3] Train-accuracy=0.730847
# [02/13/2025 21:09:04 INFO 140278783489856] Epoch[3] Time cost=4.935
# [02/13/2025 21:09:04 INFO 140278783489856] Epoch[3] Validation-accuracy=0.825893
# [02/13/2025 21:09:08 INFO 140278783489856] Epoch[4] Batch [20]#011Speed: 194.225 samples/sec#011accuracy=0.809524
# [02/13/2025 21:09:10 INFO 140278783489856] Epoch[4] Train-accuracy=0.805444
# [02/13/2025 21:09:10 INFO 140278783489856] Epoch[4] Time cost=4.916
# [02/13/2025 21:09:10 INFO 140278783489856] Epoch[4] Validation-accuracy=0.833333
# [02/13/2025 21:09:10 INFO 140278783489856] Storing the best model with validation accuracy: 0.833333
# [02/13/2025 21:09:11 INFO 140278783489856] Saved checkpoint to "/opt/ml/model/image-classification-0005.params"
# [02/13/2025 21:09:14 INFO 140278783489856] Epoch[5] Batch [20]#011Speed: 195.076 samples/sec#011accuracy=0.824405
# [02/13/2025 21:09:16 INFO 140278783489856] Epoch[5] Train-accuracy=0.817540
# [02/13/2025 21:09:16 INFO 140278783489856] Epoch[5] Time cost=4.889
# [02/13/2025 21:09:16 INFO 140278783489856] Epoch[5] Validation-accuracy=0.807292
# [02/13/2025 21:09:20 INFO 140278783489856] Epoch[6] Batch [20]#011Speed: 194.849 samples/sec#011accuracy=0.833333
# [02/13/2025 21:09:21 INFO 140278783489856] Epoch[6] Train-accuracy=0.818548
# [02/13/2025 21:09:21 INFO 140278783489856] Epoch[6] Time cost=4.896
# [02/13/2025 21:09:22 INFO 140278783489856] Epoch[6] Validation-accuracy=0.776042
# [02/13/2025 21:09:26 INFO 140278783489856] Epoch[7] Batch [20]#011Speed: 193.490 samples/sec#011accuracy=0.784226
# [02/13/2025 21:09:27 INFO 140278783489856] Epoch[7] Train-accuracy=0.788306
# [02/13/2025 21:09:27 INFO 140278783489856] Epoch[7] Time cost=4.925
# [02/13/2025 21:09:28 INFO 140278783489856] Epoch[7] Validation-accuracy=0.799107
# [02/13/2025 21:09:32 INFO 140278783489856] Epoch[8] Batch [20]#011Speed: 192.751 samples/sec#011accuracy=0.816964
# [02/13/2025 21:09:33 INFO 140278783489856] Epoch[8] Train-accuracy=0.815524
# [02/13/2025 21:09:33 INFO 140278783489856] Epoch[8] Time cost=4.954
# [02/13/2025 21:09:34 INFO 140278783489856] Epoch[8] Validation-accuracy=0.703125
# [02/13/2025 21:09:37 INFO 140278783489856] Epoch[9] Batch [20]#011Speed: 196.121 samples/sec#011accuracy=0.824405
# [02/13/2025 21:09:39 INFO 140278783489856] Epoch[9] Train-accuracy=0.826613
# [02/13/2025 21:09:39 INFO 140278783489856] Epoch[9] Time cost=4.874
# [02/13/2025 21:09:39 INFO 140278783489856] Epoch[9] Validation-accuracy=0.843750
# [02/13/2025 21:09:40 INFO 140278783489856] Storing the best model with validation accuracy: 0.843750
# [02/13/2025 21:09:40 INFO 140278783489856] Saved checkpoint to "/opt/ml/model/image-classification-0010.params"
# [02/13/2025 21:09:43 INFO 140278783489856] Epoch[10] Batch [20]#011Speed: 194.026 samples/sec#011accuracy=0.839286
# [02/13/2025 21:09:45 INFO 140278783489856] Epoch[10] Train-accuracy=0.845766
# [02/13/2025 21:09:45 INFO 140278783489856] Epoch[10] Time cost=4.916
# [02/13/2025 21:09:45 INFO 140278783489856] Epoch[10] Validation-accuracy=0.833333
# [02/13/2025 21:09:49 INFO 140278783489856] Epoch[11] Batch [20]#011Speed: 195.269 samples/sec#011accuracy=0.831845
# [02/13/2025 21:09:51 INFO 140278783489856] Epoch[11] Train-accuracy=0.831653
# [02/13/2025 21:09:51 INFO 140278783489856] Epoch[11] Time cost=4.890
# [02/13/2025 21:09:51 INFO 140278783489856] Epoch[11] Validation-accuracy=0.785714
# [02/13/2025 21:09:55 INFO 140278783489856] Epoch[12] Batch [20]#011Speed: 192.822 samples/sec#011accuracy=0.863095
# [02/13/2025 21:09:57 INFO 140278783489856] Epoch[12] Train-accuracy=0.862903
# [02/13/2025 21:09:57 INFO 140278783489856] Epoch[12] Time cost=4.915
# [02/13/2025 21:09:57 INFO 140278783489856] Epoch[12] Validation-accuracy=0.817708
# [02/13/2025 21:10:01 INFO 140278783489856] Epoch[13] Batch [20]#011Speed: 193.481 samples/sec#011accuracy=0.831845
# [02/13/2025 21:10:03 INFO 140278783489856] Epoch[13] Train-accuracy=0.847782
# [02/13/2025 21:10:03 INFO 140278783489856] Epoch[13] Time cost=4.932
# [02/13/2025 21:10:03 INFO 140278783489856] Epoch[13] Validation-accuracy=0.869792
# [02/13/2025 21:10:03 INFO 140278783489856] Storing the best model with validation accuracy: 0.869792
# [02/13/2025 21:10:04 INFO 140278783489856] Saved checkpoint to "/opt/ml/model/image-classification-0014.params"
# [02/13/2025 21:10:07 INFO 140278783489856] Epoch[14] Batch [20]#011Speed: 192.610 samples/sec#011accuracy=0.888393
# [02/13/2025 21:10:09 INFO 140278783489856] Epoch[14] Train-accuracy=0.882056
# [02/13/2025 21:10:09 INFO 140278783489856] Epoch[14] Time cost=4.944
# [02/13/2025 21:10:09 INFO 140278783489856] Epoch[14] Validation-accuracy=0.817708
# [02/13/2025 21:10:13 INFO 140278783489856] Epoch[15] Batch [20]#011Speed: 195.235 samples/sec#011accuracy=0.891369
# [02/13/2025 21:10:14 INFO 140278783489856] Epoch[15] Train-accuracy=0.885081
# [02/13/2025 21:10:14 INFO 140278783489856] Epoch[15] Time cost=4.882
# [02/13/2025 21:10:15 INFO 140278783489856] Epoch[15] Validation-accuracy=0.830357
# [02/13/2025 21:10:19 INFO 140278783489856] Epoch[16] Batch [20]#011Speed: 193.985 samples/sec#011accuracy=0.921131
# [02/13/2025 21:10:20 INFO 140278783489856] Epoch[16] Train-accuracy=0.894153
# [02/13/2025 21:10:20 INFO 140278783489856] Epoch[16] Time cost=4.915
# [02/13/2025 21:10:21 INFO 140278783489856] Epoch[16] Validation-accuracy=0.723958
# [02/13/2025 21:10:25 INFO 140278783489856] Epoch[17] Batch [20]#011Speed: 196.505 samples/sec#011accuracy=0.915179
# [02/13/2025 21:10:26 INFO 140278783489856] Epoch[17] Train-accuracy=0.914315
# [02/13/2025 21:10:26 INFO 140278783489856] Epoch[17] Time cost=4.888
# [02/13/2025 21:10:27 INFO 140278783489856] Epoch[17] Validation-accuracy=0.875000
# [02/13/2025 21:10:27 INFO 140278783489856] Storing the best model with validation accuracy: 0.875000
# [02/13/2025 21:10:27 INFO 140278783489856] Saved checkpoint to "/opt/ml/model/image-classification-0018.params"
# [02/13/2025 21:10:31 INFO 140278783489856] Epoch[18] Batch [20]#011Speed: 195.531 samples/sec#011accuracy=0.909226
# [02/13/2025 21:10:32 INFO 140278783489856] Epoch[18] Train-accuracy=0.914315
# [02/13/2025 21:10:32 INFO 140278783489856] Epoch[18] Time cost=4.891
# [02/13/2025 21:10:33 INFO 140278783489856] Epoch[18] Validation-accuracy=0.838542
# [02/13/2025 21:10:36 INFO 140278783489856] Epoch[19] Batch [20]#011Speed: 194.381 samples/sec#011accuracy=0.937500
# [02/13/2025 21:10:38 INFO 140278783489856] Epoch[19] Train-accuracy=0.935484
# [02/13/2025 21:10:38 INFO 140278783489856] Epoch[19] Time cost=4.904
# [02/13/2025 21:10:39 INFO 140278783489856] Epoch[19] Validation-accuracy=0.861607
# [02/13/2025 21:10:42 INFO 140278783489856] Epoch[20] Batch [20]#011Speed: 193.220 samples/sec#011accuracy=0.930060
# [02/13/2025 21:10:44 INFO 140278783489856] Epoch[20] Train-accuracy=0.914315
# [02/13/2025 21:10:44 INFO 140278783489856] Epoch[20] Time cost=4.929
# [02/13/2025 21:10:44 INFO 140278783489856] Epoch[20] Validation-accuracy=0.864583
# [02/13/2025 21:10:48 INFO 140278783489856] Epoch[21] Batch [20]#011Speed: 195.568 samples/sec#011accuracy=0.944940
# [02/13/2025 21:10:50 INFO 140278783489856] Epoch[21] Train-accuracy=0.943548
# [02/13/2025 21:10:50 INFO 140278783489856] Epoch[21] Time cost=4.874
# [02/13/2025 21:10:50 INFO 140278783489856] Epoch[21] Validation-accuracy=0.781250
# [02/13/2025 21:10:54 INFO 140278783489856] Epoch[22] Batch [20]#011Speed: 196.228 samples/sec#011accuracy=0.933036
# [02/13/2025 21:10:55 INFO 140278783489856] Epoch[22] Train-accuracy=0.927419
# [02/13/2025 21:10:55 INFO 140278783489856] Epoch[22] Time cost=4.864
# [02/13/2025 21:10:56 INFO 140278783489856] Epoch[22] Validation-accuracy=0.833333
# [02/13/2025 21:11:00 INFO 140278783489856] Epoch[23] Batch [20]#011Speed: 194.337 samples/sec#011accuracy=0.955357
# [02/13/2025 21:11:01 INFO 140278783489856] Epoch[23] Train-accuracy=0.952621
# [02/13/2025 21:11:01 INFO 140278783489856] Epoch[23] Time cost=4.928
# [02/13/2025 21:11:02 INFO 140278783489856] Epoch[23] Validation-accuracy=0.843750
# [02/13/2025 21:11:06 INFO 140278783489856] Epoch[24] Batch [20]#011Speed: 193.666 samples/sec#011accuracy=0.967262
# [02/13/2025 21:11:07 INFO 140278783489856] Epoch[24] Train-accuracy=0.965726
# [02/13/2025 21:11:07 INFO 140278783489856] Epoch[24] Time cost=4.901
# [02/13/2025 21:11:08 INFO 140278783489856] Epoch[24] Validation-accuracy=0.859375
# [02/13/2025 21:11:11 INFO 140278783489856] Epoch[25] Batch [20]#011Speed: 195.873 samples/sec#011accuracy=0.952381
# [02/13/2025 21:11:13 INFO 140278783489856] Epoch[25] Train-accuracy=0.954637
# [02/13/2025 21:11:13 INFO 140278783489856] Epoch[25] Time cost=4.872
# [02/13/2025 21:11:13 INFO 140278783489856] Epoch[25] Validation-accuracy=0.838542
# [02/13/2025 21:11:17 INFO 140278783489856] Epoch[26] Batch [20]#011Speed: 195.977 samples/sec#011accuracy=0.968750
# [02/13/2025 21:11:19 INFO 140278783489856] Epoch[26] Train-accuracy=0.967742
# [02/13/2025 21:11:19 INFO 140278783489856] Epoch[26] Time cost=4.879
# [02/13/2025 21:11:19 INFO 140278783489856] Epoch[26] Validation-accuracy=0.838542
# [02/13/2025 21:11:23 INFO 140278783489856] Epoch[27] Batch [20]#011Speed: 197.246 samples/sec#011accuracy=0.970238
# [02/13/2025 21:11:25 INFO 140278783489856] Epoch[27] Train-accuracy=0.972782
# [02/13/2025 21:11:25 INFO 140278783489856] Epoch[27] Time cost=4.872
# [02/13/2025 21:11:25 INFO 140278783489856] Epoch[27] Validation-accuracy=0.794643
# [02/13/2025 21:11:29 INFO 140278783489856] Epoch[28] Batch [20]#011Speed: 194.719 samples/sec#011accuracy=0.985119
# [02/13/2025 21:11:30 INFO 140278783489856] Epoch[28] Train-accuracy=0.983871
# [02/13/2025 21:11:30 INFO 140278783489856] Epoch[28] Time cost=4.891
# [02/13/2025 21:11:31 INFO 140278783489856] Epoch[28] Validation-accuracy=0.854167
# [02/13/2025 21:11:35 INFO 140278783489856] Epoch[29] Batch [20]#011Speed: 193.156 samples/sec#011accuracy=0.976190
# [02/13/2025 21:11:36 INFO 140278783489856] Epoch[29] Train-accuracy=0.973790
# [02/13/2025 21:11:36 INFO 140278783489856] Epoch[29] Time cost=4.923
# [02/13/2025 21:11:37 INFO 140278783489856] Epoch[29] Validation-accuracy=0.848958
#
# 2025-02-13 21:12:02 Uploading - Uploading generated training model
# 2025-02-13 21:12:02 Completed - Training job completed
# Training seconds: 505
# Billable seconds: 505

# %% [markdown]
# If all goes well, you'll end up with a model topping out above `.8` validation accuracy. With only 1000 training samples in the CIFAR dataset, that's pretty good. We could definitely pursue data augmentation & gathering more samples to help us improve further, but for now let's proceed to deploy our model.
#
# ### Getting ready to deploy
#
# To begin with, let's configure Model Monitor to track our deployment. We'll define a `DataCaptureConfig` below:

# %%
from sagemaker.model_monitor import DataCaptureConfig

data_capture_config = DataCaptureConfig(
    destination_s3_uri=f"s3://{bucket}/data-capture/",
    sampling_percentage=100,
    enable_capture=True
)

# %% [markdown]
# Note the `destination_s3_uri` parameter: At the end of the project, we can explore the `data_capture` directory in S3 to find crucial data about the inputs and outputs Model Monitor has observed on our model endpoint over time.
#
# With that done, deploy your model on a single `ml.m5.xlarge` instance with the data capture config attached:

# %%
deployment = img_classifier_model.deploy(
    data_capture_config=data_capture_config,
    initial_instance_count=1,
    instance_type='ml.m5.xlarge'
    )

endpoint = deployment.endpoint_name
print(endpoint)
# Out:
# [02/13/25 21:13:42] INFO     Creating model with name: image-classification-2025-02-13-21-13-42-208 ]8;id=951119;file:///home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages/sagemaker/session.py\session.py]8;;\:]8;id=108526;file:///home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages/sagemaker/session.py#4094\4094]8;;\
#                     INFO     Creating endpoint-config with name                                     ]8;id=13799;file:///home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages/sagemaker/session.py\session.py]8;;\:]8;id=686825;file:///home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages/sagemaker/session.py#5889\5889]8;;\
#                              image-classification-2025-02-13-21-13-42-208
# [02/13/25 21:13:43] INFO     Creating endpoint with name                                            ]8;id=249973;file:///home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages/sagemaker/session.py\session.py]8;;\:]8;id=759166;file:///home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages/sagemaker/session.py#4711\4711]8;;\
#                              image-classification-2025-02-13-21-13-42-208
# ------------!image-classification-2025-02-13-21-13-42-208

# %% [markdown]
# Note the endpoint name for later as well.
#
# Next, instantiate a Predictor:

# %%
from sagemaker.predictor import Predictor
predictor = Predictor(endpoint)

# %% [markdown]
# In the code snippet below we are going to prepare one of your saved images for prediction. Use the predictor to process the `payload`.

# %%
from sagemaker.serializers import IdentitySerializer
import base64

predictor.serializer = IdentitySerializer("image/png")
with open("./test/safety_bike_s_000791.png", "rb") as f:
    payload = f.read()

inference = predictor.predict(payload)

# %% [markdown]
# Your `inference` object is an array of two values, the predicted probability value for each of your classes (bicycle and motorcycle respectively.) So, for example, a value of `b'[0.91, 0.09]'` indicates the probability of being a bike is 91% and being a motorcycle is 9%.

# %%
print(inference)
# Out:
# b'[0.9978929162025452, 0.0021071406081318855]'

# %% [markdown]
# ### Draft Lambdas and Step Function Workflow
#
# Your operations team uses Step Functions to orchestrate serverless workflows. One of the nice things about Step Functions is that [workflows can call other workflows](https://docs.aws.amazon.com/step-functions/latest/dg/connect-stepfunctions.html), so the team can easily plug your workflow into the broader production architecture for Scones Unlimited.
#
# In this next stage you're going to write and deploy three Lambda functions, and then use the Step Functions visual editor to chain them together! Our functions are going to work with a simple data object:
#
# ```python
# {
#     "inferences": [], # Output of predictor.predict
#     "s3_key": "", # Source data S3 key
#     "s3_bucket": "", # Source data S3 bucket
#     "image_data": ""  # base64 encoded string containing the image data
# }
# ```
#
# A good test object that you can use for Lambda tests and Step Function executions, throughout the next section, might look like this:
#
# ```python
# {
#   "image_data": "",
#   "s3_bucket": MY_BUCKET_NAME, # Fill in with your bucket
#   "s3_key": "test/bicycle_s_000513.png"
# }
# ```
#
# Using these fields, your functions can read and write the necessary data to execute your workflow. Let's start with the first function. Your first Lambda function will copy an object from S3, base64 encode it, and then return it to the step function as `image_data` in an event.
#
# Go to the Lambda dashboard and create a new Lambda function with a descriptive name like "serializeImageData" and select thr 'Python 3.8' runtime. Add the same permissions as the SageMaker role you created earlier. (Reminder: you do this in the Configuration tab under "Permissions"). Once you're ready, use the starter code below to craft your Lambda handler:
#
# ```python
# import json
# import boto3
# import base64
#
# s3 = boto3.client('s3')
#
# def lambda_handler(event, context):
#     """A function to serialize target data from S3"""
#
#     # Get the s3 address from the Step Function event input
#     key = ## TODO: fill in
#     bucket = ## TODO: fill in
#
#     # Download the data from s3 to /tmp/image.png
#     ## TODO: fill in
#
#     # We read the data from a file
#     with open("/tmp/image.png", "rb") as f:
#         image_data = base64.b64encode(f.read())
#
#     # Pass the data back to the Step Function
#     print("Event:", event.keys())
#     return {
#         'statusCode': 200,
#         'body': {
#             "image_data": image_data,
#             "s3_bucket": bucket,
#             "s3_key": key,
#             "inferences": []
#         }
#     }
# ```
#
# The next function is responsible for the classification part - we're going to take the image output from the previous function, decode it, and then pass inferences back to the the Step Function.
#
# Because this Lambda will have runtime dependencies (i.e. the SageMaker SDK) you'll need to package them in your function. *Key reading:* https://docs.aws.amazon.com/lambda/latest/dg/python-package-create.html#python-package-create-with-dependency
#
# Create a new Lambda function with the same rights and a descriptive name, then fill in the starter code below for your classifier Lambda.
#
# ```python
# import json
# import sagemaker
# import base64
# from sagemaker.serializers import IdentitySerializer
#
# # Fill this in with the name of your deployed model
# ENDPOINT = ## TODO: fill in
#
# def lambda_handler(event, context):
#
#     # Decode the image data
#     image = base64.b64decode(## TODO: fill in)
#
#     # Instantiate a Predictor
#     predictor = ## TODO: fill in
#
#     # For this model the IdentitySerializer needs to be "image/png"
#     predictor.serializer = IdentitySerializer("image/png")
#
#     # Make a prediction:
#     inferences = ## TODO: fill in
#
#     # We return the data back to the Step Function
#     event["inferences"] = inferences.decode('utf-8')
#     return {
#         'statusCode': 200,
#         'body': json.dumps(event)
#     }
# ```
#
# Finally, we need to filter low-confidence inferences. Define a threshold between 1.00 and 0.000 for your model: what is reasonble for you? If the model predicts at `.70` for it's highest confidence label, do we want to pass that inference along to downstream systems? Make one last Lambda function and tee up the same permissions:
#
# ```python
# import json
#
#
# THRESHOLD = .93
#
#
# def lambda_handler(event, context):
#
#     # Grab the inferences from the event
#     inferences = ## TODO: fill in
#
#     # Check if any values in our inferences are above THRESHOLD
#     meets_threshold = ## TODO: fill in
#
#     # If our threshold is met, pass our data back out of the
#     # Step Function, else, end the Step Function with an error
#     if meets_threshold:
#         pass
#     else:
#         raise("THRESHOLD_CONFIDENCE_NOT_MET")
#
#     return {
#         'statusCode': 200,
#         'body': json.dumps(event)
#     }
# ```
# Once you have tested the lambda functions, save the code for each lambda function in a python script called 'lambda.py'.
#
# With your lambdas in place, you can use the Step Functions visual editor to construct a workflow that chains them together. In the Step Functions console you'll have the option to author a Standard step function *Visually*.
#
# When the visual editor opens, you'll have many options to add transitions in your workflow. We're going to keep it simple and have just one: to invoke Lambda functions. Add three of them chained together. For each one, you'll be able to select the Lambda functions you just created in the proper order, filter inputs and outputs, and give them descriptive names.
#
# Make sure that you:
#
# 1. Are properly filtering the inputs and outputs of your invokations (e.g. `$.body`)
# 2. Take care to remove the error handling from the last function - it's supposed to "fail loudly" for your operations colleagues!
#
# Take a screenshot of your working step function in action and export the step function as JSON for your submission package.

# %% [markdown]
# Great! Now you can use the files in `./test` as test files for our workflow. Depending on our threshold, our workflow should reliably pass predictions about images from `./test` on to downstream systems, while erroring out for inferences below our confidence threshold!
#
# ### Testing and Evaluation
#
# Do several step function invokations using data from the `./test` folder. This process should give you confidence that the workflow both *succeeds* AND *fails* as expected. In addition, SageMaker Model Monitor will generate recordings of your data and inferences which we can visualize.
#
# Here's a function that can help you generate test inputs for your invokations:

# %%
import random
import boto3
import json


def generate_test_case():
    # Setup s3 in boto3
    s3 = boto3.resource('s3')
    
    # Randomly pick from sfn or test folders in our bucket
    objects = s3.Bucket(bucket).objects.filter(Prefix="test")
    
    # Grab any random object key from that folder!
    obj = random.choice([x.key for x in objects])
    
    return json.dumps({
        "image_data": "",
        "s3_bucket": bucket,
        "s3_key": obj
    })
generate_test_case()
# Out:
# '{"image_data": "", "s3_bucket": "ml-etl-project", "s3_key": "test/motorcycle_s_000685.png"}'

# %% [markdown]
# In the Step Function dashboard for your new function, you can create new executions and copy in the generated test cases. Do several executions so that you can generate data you can evaluate and visualize.
#
# Once you've done several executions, let's visualize the record of our inferences. Pull in the JSONLines data from your inferences like so:

# %%
from sagemaker.s3 import S3Downloader

# In S3 your data will be saved to a datetime-aware path
# Find a path related to a datetime you're interested in
data_path = "s3://ml-etl-project/data-capture/image-classification-2025-02-13-21-13-42-208/AllTraffic/2025/02/13/22/"

## TODO: fill in the path to your captured data
S3Downloader.download(data_path, "captured-data")

# Feel free to repeat this multiple times and pull in more data
file_handles = os.listdir("./captured-data")
print(file_handles)
# Out:
# [02/13/25 22:36:55] INFO     Skipping checksum validation. Response did not contain one of the  ]8;id=991748;file:///home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages/botocore/httpchecksum.py\httpchecksum.py]8;;\:]8;id=26800;file:///home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages/botocore/httpchecksum.py#481\481]8;;\
#                              following algorithms: ['crc64nvme', 'crc32c', 'crc32', 'sha1',
#                              'sha256'].
#                     INFO     Skipping checksum validation. Response did not contain one of the  ]8;id=506378;file:///home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages/botocore/httpchecksum.py\httpchecksum.py]8;;\:]8;id=181243;file:///home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages/botocore/httpchecksum.py#481\481]8;;\
#                              following algorithms: ['crc64nvme', 'crc32c', 'crc32', 'sha1',
#                              'sha256'].
#                     INFO     Skipping checksum validation. Response did not contain one of the  ]8;id=565642;file:///home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages/botocore/httpchecksum.py\httpchecksum.py]8;;\:]8;id=198665;file:///home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages/botocore/httpchecksum.py#481\481]8;;\
#                              following algorithms: ['crc64nvme', 'crc32c', 'crc32', 'sha1',
#                              'sha256'].
#                     INFO     Skipping checksum validation. Response did not contain one of the  ]8;id=544212;file:///home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages/botocore/httpchecksum.py\httpchecksum.py]8;;\:]8;id=117266;file:///home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages/botocore/httpchecksum.py#481\481]8;;\
#                              following algorithms: ['crc64nvme', 'crc32c', 'crc32', 'sha1',
#                              'sha256'].
#                     INFO     Skipping checksum validation. Response did not contain one of the  ]8;id=343760;file:///home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages/botocore/httpchecksum.py\httpchecksum.py]8;;\:]8;id=871976;file:///home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages/botocore/httpchecksum.py#481\481]8;;\
#                              following algorithms: ['crc64nvme', 'crc32c', 'crc32', 'sha1',
#                              'sha256'].
#                     INFO     Skipping checksum validation. Response did not contain one of the  ]8;id=246613;file:///home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages/botocore/httpchecksum.py\httpchecksum.py]8;;\:]8;id=417930;file:///home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages/botocore/httpchecksum.py#481\481]8;;\
#                              following algorithms: ['crc64nvme', 'crc32c', 'crc32', 'sha1',
#                              'sha256'].
#                     INFO     Skipping checksum validation. Response did not contain one of the  ]8;id=530020;file:///home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages/botocore/httpchecksum.py\httpchecksum.py]8;;\:]8;id=230408;file:///home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages/botocore/httpchecksum.py#481\481]8;;\
#                              following algorithms: ['crc64nvme', 'crc32c', 'crc32', 'sha1',
#                              'sha256'].
# ['21-28-564-f8b2100a-afbd-4acf-9ed7-c5b8b6071d51.jsonl', '00-19-563-18dbfbc7-1f22-4812-8f4c-75eabb3ad7e2.jsonl', '19-00-431-bc30d259-ac69-4e27-b028-12c90f8960ca.jsonl', '14-32-145-df6d7b5a-a69c-4add-9962-9b3bf35e4d58.jsonl', '16-35-260-f035a995-375a-421c-afc0-ff19fff83473.jsonl', '23-50-122-a9822a73-4a9b-43c9-9e97-30e121aedbf2.jsonl', '25-06-373-ed7d7578-c670-4fe4-a677-e624609f2d27.jsonl', '05-08-615-59887065-1a77-4876-9bc3-eaf785e2cc0d.jsonl', '11-07-718-8af36318-79ec-4cbc-9ca9-db5fce2735b8.jsonl', '33-08-433-d98c6834-1114-40f7-a3eb-a85afcb02b6a.jsonl', '09-27-252-03ed8855-91b1-48b0-87e4-266d269a2ef4.jsonl', '31-28-061-c06e3232-4bea-4aef-8038-1eeb73d21d2d.jsonl', '30-26-467-4dfe3ff8-ca3e-4687-a959-08267c6ca466.jsonl', '15-34-073-bf620f57-bbbe-4ff2-9e2d-e3d2bd5a6376.jsonl', '13-19-546-bb0da0d9-2359-4b3f-a2c7-3f51dca22b39.jsonl', '01-22-284-e053779b-591e-4fe2-adb3-137c562d68a0.jsonl', '22-13-180-8996373d-ffab-4e30-9f9a-1e0c9155523b.jsonl']

# %% [markdown]
# The data are in JSONLines format, where multiple valid JSON objects are stacked on top of eachother in a single `jsonl` file. We'll import an open-source library, `jsonlines` that was purpose built for parsing this format.

# %%
# !pip install jsonlines
import jsonlines
# Out:
# Collecting jsonlines
#   Downloading jsonlines-4.0.0-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: attrs>=19.2.0 in /home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages (from jsonlines) (23.2.0)
# Downloading jsonlines-4.0.0-py3-none-any.whl (8.7 kB)
# Installing collected packages: jsonlines
# Successfully installed jsonlines-4.0.0

# %% [markdown]
# Now we can extract the data from each of the source files:

# %%
import os

# List the file names we downloaded
file_handles = os.listdir("./captured-data")

# Dump all the data into an array
json_data = []
for jsonl in file_handles:
    with jsonlines.open(f"./captured-data/{jsonl}") as f:
        json_data.append(f.read())

# %% [markdown]
# The data should now be a list of dictionaries, with significant nesting. We'll give you an example of some code that grabs data out of the objects and visualizes it:

# %%
# Define how we'll get our data
def simple_getter(obj):
    inferences = obj["captureData"]["endpointOutput"]["data"]
    timestamp = obj["eventMetadata"]["inferenceTime"]
    return json.loads(inferences), timestamp

simple_getter(json_data[0])
# Out:
# ([0.8296934962272644,
#   0.17000412940979004,
#   4.044975867145695e-05,
#   4.374074705992825e-05,
#   2.1241779904812574e-05,
#   4.137461291975342e-05,
#   4.535475090960972e-05,
#   4.874233127338812e-05,
#   3.20338731398806e-05,
#   2.9330489269341342e-05],
#  '2025-02-07T03:21:28Z')

# %% [markdown]
# Finally, here's an example of a visualization you can build with this data. In this last part, you will take some time and build your own - the captured data has the input images, the resulting inferences, and the timestamps.

# %%
# Populate the data for the x and y axis
x = []
y = []
for obj in json_data:
    inference, timestamp = simple_getter(obj)
    
    y.append(max(inference))
    x.append(timestamp)

# Todo: here is an visualization example, take some time to build another visual that helps monitor the result
# Plot the data
plt.scatter(x, y, c=['r' if k<.94 else 'b' for k in y ])
plt.axhline(y=0.94, color='g', linestyle='--')
plt.ylim(bottom=.88)

# Add labels
plt.ylabel("Confidence")
plt.suptitle("Observed Recent Inferences", size=14)
plt.title("Pictured with confidence threshold for production use", size=10)

# Give it some pizzaz!
plt.style.use("Solarize_Light2")
plt.gcf().autofmt_xdate()
# Out:
# [02/13/25 22:38:09] INFO     Using categorical units to plot a list of strings that are all         ]8;id=432102;file:///home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages/matplotlib/category.py\category.py]8;;\:]8;id=146726;file:///home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages/matplotlib/category.py#224\224]8;;\
#                              parsable as floats or dates. If these strings should be plotted as
#                              numbers, cast to the appropriate data type before plotting.
#                     INFO     Using categorical units to plot a list of strings that are all         ]8;id=687578;file:///home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages/matplotlib/category.py\category.py]8;;\:]8;id=793161;file:///home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages/matplotlib/category.py#224\224]8;;\
#                              parsable as floats or dates. If these strings should be plotted as
#                              numbers, cast to the appropriate data type before plotting.

# %%
#Creating a bar plot to display each result
x = []
y = []
for obj in json_data:
    inference, timestamp = simple_getter(obj)
    
    y.append(max(inference))
    x.append(timestamp)
    
plt.bar(x, y, color ='blue',
        width = 0.5)

# Add labels
plt.ylabel("Confidence")
plt.suptitle("Observed Recent Inferences Bicylce Class Only", size=14)
plt.title("Confidence for each inference result", size=10)

# Give it some pizzaz!
plt.style.use("Solarize_Light2")
plt.gcf().autofmt_xdate()
plt.show()
# Out:
# [02/13/25 22:42:36] INFO     Using categorical units to plot a list of strings that are all         ]8;id=771191;file:///home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages/matplotlib/category.py\category.py]8;;\:]8;id=22106;file:///home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages/matplotlib/category.py#224\224]8;;\
#                              parsable as floats or dates. If these strings should be plotted as
#                              numbers, cast to the appropriate data type before plotting.
#                     INFO     Using categorical units to plot a list of strings that are all         ]8;id=247789;file:///home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages/matplotlib/category.py\category.py]8;;\:]8;id=603605;file:///home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages/matplotlib/category.py#224\224]8;;\
#                              parsable as floats or dates. If these strings should be plotted as
#                              numbers, cast to the appropriate data type before plotting.

# %% [markdown]
# ### Todo: build your own visualization

# %% [markdown]
# ### Congratulations!
#
# You've reached the end of the project. In this project you created an event-drivent ML workflow that can be incorporated into the Scones Unlimited production architecture. You used the SageMaker Estimator API to deploy your SageMaker Model and Endpoint, and you used AWS Lambda and Step Functions to orchestrate your ML workflow. Using SageMaker Model Monitor, you instrumented and observed your Endpoint, and at the end of the project you built a visualization to help stakeholders understand the performance of the Endpoint over time. If you're up for it, you can even go further with these stretch goals:
#
# * Extend your workflow to incorporate more classes: the CIFAR dataset includes other vehicles that Scones Unlimited can identify with this model.
# * Modify your event driven workflow: can you rewrite your Lambda functions so that the workflow can process multiple image inputs in parallel? Can the Step Function "fan out" to accomodate this new workflow?
# * Consider the test data generator we provided for you. Can we use it to create a "dummy data" generator, to simulate a continuous stream of input data? Or a big paralell load of data?
# * What if we want to get notified every time our step function errors out? Can we use the Step Functions visual editor in conjunction with a service like SNS to accomplish this? Try it out!
